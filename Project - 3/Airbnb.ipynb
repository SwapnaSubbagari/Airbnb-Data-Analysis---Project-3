# %%
#import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, Boolean, delete

# %%
#import CSV data
csv = 'Resources/AB_US_2020.csv'
#data = pd.read_csv(csv)
data = pd.read_csv(csv, low_memory=False)
data.head(5)
# Out:
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     60               1                138    16/02/20
# 1  Entire home/apt    470               1                114    07/09/20
# 2  Entire home/apt     75              30                 89    30/11/19
# 3  Entire home/apt     90               1                267    22/09/20
# 4     Private room    125              30                 58    19/10/15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.14                               1                 0
# 1               1.03                              11               288
# 2               0.81                               2               298
# 3               2.39                               5                 0
# 4               0.52                               1                 0
#
#         city
# 0  Asheville
# 1  Asheville
# 2  Asheville
# 3  Asheville
# 4  Asheville

# %%
#drop unneeded columns
Airbnb_Rental_Property_information = data.drop(['id','name','host_id','neighbourhood_group','last_review'], axis=1)
Airbnb_Rental_Property_information.head()
# Out:
#    host_name neighbourhood  latitude  longitude        room_type  price  \
# 0    Evelyne         28804  35.65146  -82.62792     Private room     60
# 1    Celeste         28801  35.59779  -82.55540  Entire home/apt    470
# 2       Lisa         28801  35.60670  -82.55563  Entire home/apt     75
# 3    BonPaul         28806  35.57864  -82.59578  Entire home/apt     90
# 4  Elizabeth         28801  35.61442  -82.54127     Private room    125
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                138               1.14
# 1               1                114               1.03
# 2              30                 89               0.81
# 3               1                267               2.39
# 4              30                 58               0.52
#
#    calculated_host_listings_count  availability_365       city
# 0                               1                 0  Asheville
# 1                              11               288  Asheville
# 2                               2               298  Asheville
# 3                               5                 0  Asheville
# 4                               1                 0  Asheville

# %%
cities = ['New York City', 'Los Angeles','Hawaii',
'San Diego','Broward County','Austin','Clark County','Washington D.C.',
'San Clara Country',    
'San Francisco',        
'Oakland',     
'San Mateo County',
'Santa Cruz County',     
'Pacific Grove']

data = Airbnb_Rental_Property_information[Airbnb_Rental_Property_information['city'].isin(cities)]         
data = data.reset_index(drop = True)
data.info()

data.to_csv(r'forjson.csv', index=False)

data['city'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171135 entries, 0 to 171134
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_name                       171105 non-null  object
#  1   neighbourhood                   171135 non-null  object
#  2   latitude                        171135 non-null  float64
#  3   longitude                       171135 non-null  float64
#  4   room_type                       171135 non-null  object
#  5   price                           171135 non-null  int64
#  6   minimum_nights                  171135 non-null  int64
#  7   number_of_reviews               171135 non-null  int64
#  8   reviews_per_month               132309 non-null  float64
#  9   calculated_host_listings_count  171135 non-null  int64
#  10  availability_365                171135 non-null  int64
#  11  city                            171135 non-null  object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 15.7+ MB
# New York City        45756
# Los Angeles          31536
# Hawaii               22434
# San Diego            12404
# Broward County       10858
# Austin               10436
# Clark County          8408
# Washington D.C.       7350
# San Clara Country     7091
# San Francisco         7053
# Oakland               3204
# San Mateo County      2855
# Santa Cruz County     1571
# Pacific Grove          179
# Name: city, dtype: int64

# %%
#drop duplicates for specific longitude and latitude (i.e., variables)
newdf2 = data.drop_duplicates(subset=['latitude', 'longitude'])
newdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165733 entries, 0 to 171134
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_name                       165703 non-null  object
#  1   neighbourhood                   165733 non-null  object
#  2   latitude                        165733 non-null  float64
#  3   longitude                       165733 non-null  float64
#  4   room_type                       165733 non-null  object
#  5   price                           165733 non-null  int64
#  6   minimum_nights                  165733 non-null  int64
#  7   number_of_reviews               165733 non-null  int64
#  8   reviews_per_month               128999 non-null  float64
#  9   calculated_host_listings_count  165733 non-null  int64
#  10  availability_365                165733 non-null  int64
#  11  city                            165733 non-null  object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 16.4+ MB

# %%
newdf2.shape
# Out:
# (165733, 12)

# %%
#export to csv file
newdf2.to_csv(r'Airbnb.csv', index=False)

# %%
#get mean and median data for key variables
mean_price = newdf2.groupby('city').agg({'price': 'mean'},{'reviews_per_month': 'mean'} )
mean_availability = newdf2.groupby('city').agg({'availability_365': 'mean'})
median_price = newdf2.groupby('city').agg({'price': 'median'})
median_reviews = newdf2.groupby('city').agg({'reviews_per_month': 'median'})
median_availability = newdf2.groupby('city').agg({'availability_365': 'median'})

# %%
df1 = pd.merge(mean_price, mean_availability, on="city")
df2 = pd.merge(df1,median_price, on="city")
df3 = pd.merge(df2,median_reviews, on="city")
df4 = pd.merge(df3,median_availability, on="city")

df4.columns = ['mean_price', 'mean_availability', 'median_price','median_reviews', 'median_availability']
df4
# Out:
#                    mean_price  mean_availability  median_price  \
# city
# Austin             279.600680         121.076630         135.0
# Broward County     232.555300         199.755492         129.0
# Clark County       214.700618         186.286886         138.0
# Hawaii             313.541600         223.395132         188.0
# Los Angeles        224.371845         170.762913         108.0
# New York City      148.697597         119.036517         100.0
# Oakland            139.956604         114.943396          95.5
# Pacific Grove      255.924419         173.360465         223.5
# San Clara Country  162.789367         167.469662         100.0
# San Diego          320.618906         143.299596         140.0
# San Francisco      254.456023         162.538909         140.0
# San Mateo County   184.882751         172.251604         125.0
# Santa Cruz County  257.444087         151.877892         195.0
# Washington D.C.    178.367277         135.606448         100.0
#
#                    median_reviews  median_availability
# city
# Austin                      0.680                   68
# Broward County              0.880                  195
# Clark County                1.110                  169
# Hawaii                      0.550                  259
# Los Angeles                 0.860                  158
# New York City               0.360                   45
# Oakland                     0.630                   72
# Pacific Grove               0.965                  186
# San Clara Country           0.800                  158
# San Diego                   0.990                  101
# San Francisco               0.670                  151
# San Mateo County            1.270                  162
# Santa Cruz County           1.140                  141
# Washington D.C.             0.910                   89

# %%
#Visualize frequency of rentals by specific city
sns.countplot("city",data=newdf2)
plt.xticks(rotation=90)
plt.savefig('static/images/Count_of_Rentalproperties_byCity.png', bbox_inches='tight')
# Out:
# C:\Users\Other\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#visualize room type
newdf2['room_type'].value_counts().plot(kind='barh', figsize=(6,4), 
                                     edgecolor=(0,0,0),color='r', title='Type of location')
plt.savefig('static/images/Count_of_Rental Type.png', bbox_inches='tight')

# %%
# view descriptive statis for price
newdf2['price'].describe()
# Out:
# count    165733.000000
# mean        220.324238
# std         598.120065
# min           0.000000
# 25%          75.000000
# 50%         121.000000
# 75%         200.000000
# max       24999.000000
# Name: price, dtype: float64

# %%
# Create the bins in which Data will be held

bins = [0, 100, 200, 400, np.inf]

# Create the names for the five bins
group_names = ["100 and below", "100 to 200", "200 to 400", "400 or more"]


newdf2['price_bins'] = pd.cut(newdf2['price'], bins, labels=group_names, include_lowest=True)
newdf2 = newdf2.reset_index(drop=True)
newdf2
# Out:
# <ipython-input-13-bad50c6783fb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2['price_bins'] = pd.cut(newdf2['price'], bins, labels=group_names, include_lowest=True)
#         host_name                                      neighbourhood  \
# 0           Paddy                                              78702
# 1           Paddy                                              78702
# 2          Sylvia                                              78702
# 3           Peggy                                              78704
# 4       Elizabeth                                              78729
# ...           ...                                                ...
# 165728      Marci  Downtown, Chinatown, Penn Quarters, Mount Vern...
# 165729     Thomas                      Brookland, Brentwood, Langdon
# 165730     Bassem                                 Shaw, Logan Circle
# 165731    Michael     Kalorama Heights, Adams Morgan, Lanier Heights
# 165732       Adam  Edgewood, Bloomingdale, Truxton Circle, Eckington
#
#          latitude  longitude        room_type  price  minimum_nights  \
# 0       30.277500 -97.713980  Entire home/apt    177               7
# 1       30.275770 -97.713790     Private room    114              30
# 2       30.261120 -97.734480  Entire home/apt     99               2
# 3       30.246300 -97.763610  Entire home/apt     46              30
# 4       30.456970 -97.784220     Private room     39               1
# ...           ...        ...              ...    ...             ...
# 165728  38.903880 -77.029730  Entire home/apt    104               1
# 165729  38.920820 -76.990980  Entire home/apt    151               2
# 165730  38.911170 -77.033540  Entire home/apt    240               2
# 165731  38.926630 -77.044360  Entire home/apt     60              21
# 165732  38.911569 -77.009431  Entire home/apt     79               7
#
#         number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                      24               0.17                               3
# 1                       9               0.06                               3
# 2                     535               3.81                               1
# 3                      20               0.14                               2
# 4                     257               2.02                               1
# ...                   ...                ...                             ...
# 165728                  0                NaN                               2
# 165729                  0                NaN                               1
# 165730                  0                NaN                               1
# 165731                  0                NaN                               5
# 165732                  0                NaN                               2
#
#         availability_365             city     price_bins
# 0                    136           Austin     100 to 200
# 1                      0           Austin     100 to 200
# 2                    359           Austin  100 and below
# 3                     63           Austin  100 and below
# 4                     46           Austin  100 and below
# ...                  ...              ...            ...
# 165728                99  Washington D.C.     100 to 200
# 165729               300  Washington D.C.     100 to 200
# 165730               173  Washington D.C.     200 to 400
# 165731               362  Washington D.C.  100 and below
# 165732                62  Washington D.C.  100 and below
#
# [165733 rows x 13 columns]

# %%
#Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func


engine = create_engine('sqlite:///save_pandas.db', echo=True)

sqlite_connection = engine.connect()

sqlite_table = "Airbnb_Analysis"
newdf2.to_sql(sqlite_table, sqlite_connection, if_exists='replace')
# Out:
# 2021-10-05 21:33:35,250 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Airbnb_Analysis")
# 2021-10-05 21:33:35,254 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,257 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Airbnb_Analysis")
# 2021-10-05 21:33:35,258 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,261 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-10-05 21:33:35,262 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,265 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Airbnb_Analysis")
# 2021-10-05 21:33:35,266 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,269 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-10-05 21:33:35,270 INFO sqlalchemy.engine.Engine [raw sql] ('Airbnb_Analysis',)
# 2021-10-05 21:33:35,273 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Airbnb_Analysis")
# 2021-10-05 21:33:35,274 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,276 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Airbnb_Analysis")
# 2021-10-05 21:33:35,277 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,278 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-10-05 21:33:35,279 INFO sqlalchemy.engine.Engine [raw sql] ('Airbnb_Analysis',)
# 2021-10-05 21:33:35,294 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Airbnb_Analysis")
# 2021-10-05 21:33:35,297 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,310 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_Airbnb_Analysis_index")
# 2021-10-05 21:33:35,314 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,323 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Airbnb_Analysis")
# 2021-10-05 21:33:35,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,338 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_Airbnb_Analysis_index")
# 2021-10-05 21:33:35,340 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-10-05 21:33:35,343 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-10-05 21:33:35,345 INFO sqlalchemy.engine.Engine [raw sql] ('Airbnb_Analysis',)
# 2021-10-05 21:33:35,366 INFO sqlalchemy.engine.Engine
# DROP TABLE "Airbnb_Analysis"
# 2021-10-05 21:33:35,370 INFO sqlalchemy.engine.Engine [no key 0.00351s] ()
# 2021-10-05 21:33:35,580 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-05 21:33:35,598 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Airbnb_Analysis" (
# 	"index" BIGINT,
# 	host_name TEXT,
# 	neighbourhood TEXT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	room_type TEXT,
# 	price BIGINT,
# 	minimum_nights BIGINT,
# 	number_of_reviews BIGINT,
# 	reviews_per_month FLOAT,
# 	calculated_host_listings_count BIGINT,
# 	availability_365 BIGINT,
# 	city TEXT,
# 	price_bins TEXT
# )
#
#
# 2021-10-05 21:33:35,602 INFO sqlalchemy.engine.Engine [no key 0.00399s] ()
# 2021-10-05 21:33:35,634 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-05 21:33:35,636 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Airbnb_Analysis_index" ON "Airbnb_Analysis" ("index")
# 2021-10-05 21:33:35,637 INFO sqlalchemy.engine.Engine [no key 0.00137s] ()
# 2021-10-05 21:33:35,648 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-05 21:33:35,969 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-10-05 21:33:42,096 INFO sqlalchemy.engine.Engine INSERT INTO "Airbnb_Analysis" ("index", host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365, city, price_bins) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-10-05 21:33:42,097 INFO sqlalchemy.engine.Engine [generated in 4.72020s] ((0, 'Paddy', '78702', 30.2775, -97.71398, 'Entire home/apt', 177, 7, 24, 0.17, 3, 136, 'Austin', '100 to 200'), (1, 'Paddy', '78702', 30.27577, -97.71379, 'Private room', 114, 30, 9, 0.06, 3, 0, 'Austin', '100 to 200'), (2, 'Sylvia', '78702', 30.26112, -97.73448, 'Entire home/apt', 99, 2, 535, 3.81, 1, 359, 'Austin', '100 and below'), (3, 'Peggy', '78704', 30.2463, -97.76361, 'Entire home/apt', 46, 30, 20, 0.14, 2, 63, 'Austin', '100 and below'), (4, 'Elizabeth', '78729', 30.45697, -97.78422, 'Private room', 39, 1, 257, 2.02, 1, 46, 'Austin', '100 and below'), (5, 'Todd', '78704', 30.24829, -97.73726, 'Entire home/apt', 99, 30, 112, 0.85, 1, 31, 'Austin', '100 and below'), (6, 'Amy', '78704', 30.26027, -97.76503, 'Entire home/apt', 139, 3, 232, 2.11, 2, 162, 'Austin', '100 to 200'), (7, 'Steven', '78748', 30.15645, -97.82411, 'Entire home/apt', 300, 1, 28, 0.35, 1, 260, 'Austin', '200 to 400')  ... displaying 10 of 165733 total bound parameter sets ...  (165731, 'Michael', 'Kalorama Heights, Adams Morgan, Lanier Heights', 38.92663, -77.04436, 'Entire home/apt', 60, 21, 0, None, 5, 362, 'Washington D.C.', '100 and below'), (165732, 'Adam', 'Edgewood, Bloomingdale, Truxton Circle, Eckington', 38.91156921, -77.00943076, 'Entire home/apt', 79, 7, 0, None, 2, 62, 'Washington D.C.', '100 and below'))
# 2021-10-05 21:33:44,800 INFO sqlalchemy.engine.Engine COMMIT
# 2021-10-05 21:33:44,859 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-10-05 21:33:44,860 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
from sqlalchemy.orm import Session
session = Session(engine)
engine.execute('select * from Airbnb_Analysis').fetchall()
# pet = session.query(Airbnb_Analysis).filter_by(Host_Name="Paddy").first()
# Out:
# 2021-10-05 21:33:44,931 INFO sqlalchemy.engine.Engine select * from Airbnb_Analysis
# 2021-10-05 21:33:44,933 INFO sqlalchemy.engine.Engine [raw sql] ()
# [(0, 'Paddy', '78702', 30.2775, -97.71398, 'Entire home/apt', 177, 7, 24, 0.17, 3, 136, 'Austin', '100 to 200'),
#  (1, 'Paddy', '78702', 30.27577, -97.71379, 'Private room', 114, 30, 9, 0.06, 3, 0, 'Austin', '100 to 200'),
#  (2, 'Sylvia', '78702', 30.26112, -97.73448, 'Entire home/apt', 99, 2, 535, 3.81, 1, 359, 'Austin', '100 and below'),
#  (3, 'Peggy', '78704', 30.2463, -97.76361, 'Entire home/apt', 46, 30, 20, 0.14, 2, 63, 'Austin', '100 and below'),
#  (4, 'Elizabeth', '78729', 30.45697, -97.78422, 'Private room', 39, 1, 257, 2.02, 1, 46, 'Austin', '100 and below'),
#  (5, 'Todd', '78704', 30.24829, -97.73726, 'Entire home/apt', 99, 30, 112, 0.85, 1, 31, 'Austin', '100 and below'),
#  (6, 'Amy', '78704', 30.26027, -97.76503, 'Entire home/apt', 139, 3, 232, 2.11, 2, 162, 'Austin', '100 to 200'),
#  (7, 'Steven', '78748', 30.15645, -97.82411, 'Entire home/apt', 300, 1, 28, 0.35, 1, 260, 'Austin', '200 to 400'),
#  (8, 'Dani', '78704', 30.24417, -97.73988, 'Entire home/apt', 176, 1, 99, 1.07, 11, 115, 'Austin', '100 to 200'),
#  (9, 'April', '78705', 30.29422, -97.74618, 'Entire home/apt', 220, 30, 38, 0.68, 1, 170, 'Austin', '200 to 400'),
#  (10, 'Stacey', '78759', 30.38957, -97.76216, 'Entire home/apt', 150, 30, 10, 0.08, 1, 357, 'Austin', '100 to 200'),
#  (11, 'David', '78741', 30.23614, -97.73225, 'Entire home/apt', 50, 31, 37, 0.29, 1, 316, 'Austin', '100 and below'),
#  (12, 'Gina', '78703', 30.28027, -97.75596, 'Entire home/apt', 125, 2, 164, 1.28, 1, 4, 'Austin', '100 to 200'),
#  (13, 'Elana', '78757', 30.33766, -97.73726, 'Entire home/apt', 117, 7, 34, 0.27, 1, 245, 'Austin', '100 to 200'),
#  (14, 'Tiffany', '78749', 30.20273, -97.84439, 'Entire home/apt', 55, 1, 9, 0.07, 1, 260, 'Austin', '100 and below'),
#  (15, 'Chris', '78727', 30.4303, -97.69125, 'Private room', 38, 30, 38, 0.59, 1, 260, 'Austin', '100 and below'),
#  (16, 'Susan', '78703', 30.29923, -97.77789, 'Entire home/apt', 59, 2, 158, 1.99, 2, 0, 'Austin', '100 and below'),
#  (17, 'Robbie', '78731', 30.35141, -97.76323, 'Entire home/apt', 350, 2, 30, 0.26, 1, 337, 'Austin', '200 to 400'),
#  (18, 'Belinda', '78758', 30.37641, -97.70926, 'Private room', 34, 30, 3, 0.16, 1, 347, 'Austin', '100 and below'),
#  (19, 'Flip', '78705', 30.28625, -97.75022, 'Entire home/apt', 117, 30, 30, 0.25, 2, 294, 'Austin', '100 to 200'),
#  (20, 'Stephanie', '78704', 30.2444, -97.75121, 'Entire home/apt', 150, 2, 174, 1.5, 2, 86, 'Austin', '100 to 200'),
#  (21, 'Lois', '78704', 30.25596, -97.76866, 'Entire home/apt', 102, 1, 682, 5.77, 2, 363, 'Austin', '100 to 200'),
#  (22, 'Drew', '78751', 30.31171, -97.72455, 'Entire home/apt', 51, 2, 499, 4.24, 1, 90, 'Austin', '100 and below'),
#  (23, 'Lois', '78704', 30.2607, -97.77194, 'Entire home/apt', 155, 2, 110, 0.96, 2, 287, 'Austin', '100 to 200'),
#  (24, 'Particular Properties', '78704', 30.25775, -97.76354, 'Entire home/apt', 159, 2, 390, 3.37, 2, 104, 'Austin', '100 to 200'),
#  (25, 'Dolina', '78704', 30.23152, -97.76434, 'Entire home/apt', 119, 2, 441, 3.79, 1, 0, 'Austin', '100 to 200'),
#  (26, 'Jason', '78704', 30.23616, -97.76446, 'Entire home/apt', 249, 2, 30, 0.82, 1, 90, 'Austin', '200 to 400'),
#  (27, 'Stephanie', '78704', 30.24501, -97.74986, 'Entire home/apt', 150, 2, 143, 1.23, 2, 86, 'Austin', '100 to 200'),
#  (28, 'Alyson & Max', '78704', 30.2532, -97.77891, 'Private room', 225, 3, 38, 0.33, 4, 0, 'Austin', '200 to 400'),
#  (29, 'Becca', '78704', 30.24604, -97.75329, 'Entire home/apt', 470, 2, 40, 0.35, 1, 363, 'Austin', '400 or more'),
#  (30, 'Ellen And Andy', '78731', 30.313, -97.75066, 'Entire home/apt', 85, 3, 349, 3.01, 1, 250, 'Austin', '100 and below'),
#  (31, 'Becky', '78729', 30.44755, -97.76115, 'Private room', 49, 3, 17, 1.21, 1, 0, 'Austin', '100 and below'),
#  (32, 'Vivian', '78727', 30.41519, -97.73019, 'Entire home/apt', 230, 2, 26, 0.22, 1, 1, 'Austin', '200 to 400'),
#  (33, 'Christina', '78705', 30.28985, -97.7451, 'Entire home/apt', 112, 30, 47, 0.41, 2, 301, 'Austin', '100 to 200'),
#  (34, 'Amy & Justin', '78704', 30.24422, -97.77885, 'Entire home/apt', 93, 2, 206, 1.79, 1, 364, 'Austin', '100 and below'),
#  (35, 'David', '78702', 30.24773, -97.72584, 'Entire home/apt', 110, 2, 267, 2.31, 2, 217, 'Austin', '100 to 200'),
#  (36, 'Kelly', '78703', 30.29187, -97.76824, 'Entire home/apt', 104, 2, 304, 2.62, 2, 355, 'Austin', '100 to 200'),
#  (37, 'Ash', '78703', 30.27577, -97.75608, 'Entire home/apt', 90, 2, 202, 1.74, 2, 352, 'Austin', '100 and below'),
#  (38, 'Kevin And Bob', '78722', 30.29138, -97.71907, 'Entire home/apt', 100, 2, 175, 1.5, 1, 175, 'Austin', '100 and below'),
#  (39, 'Peter', '78702', 30.26775, -97.72695, 'Entire home/apt', 485, 2, 142, 2.14, 1, 339, 'Austin', '400 or more'),
#  (40, 'Lynn', '78702', 30.25517, -97.72458, 'Entire home/apt', 400, 2, 16, 0.14, 1, 0, 'Austin', '200 to 400'),
#  (41, 'Krista', '78704', 30.23872, -97.74521, 'Entire home/apt', 80, 20, 41, 0.35, 1, 171, 'Austin', '100 and below'),
#  (42, 'Chuck', '78702', 30.2699, -97.73222, 'Entire home/apt', 139, 1, 3, 0.03, 1, 12, 'Austin', '100 to 200'),
#  (43, 'Carlos', '78704', 30.25177, -97.77888, 'Entire home/apt', 175, 2, 16, 0.16, 2, 352, 'Austin', '100 to 200'),
#  (44, 'Carlos', '78704', 30.25003, -97.77859, 'Entire home/apt', 149, 2, 22, 0.31, 2, 344, 'Austin', '100 to 200'),
#  (45, 'Jordan', '78725', 30.25923, -97.66815, 'Entire home/apt', 190, 2, 2, 0.03, 1, 351, 'Austin', '100 to 200'),
#  (46, 'Keith And Shannon', '78704', 30.25625, -97.76766, 'Entire home/apt', 750, 3, 90, 2.09, 1, 0, 'Austin', '400 or more'),
#  (47, 'Julia', '78701', 30.2752, -97.74863, 'Entire home/apt', 240, 1, 6, 0.05, 3, 0, 'Austin', '200 to 400'),
#  (48, 'E. Dixie', '78702', 30.27324, -97.71173, 'Private room', 65, 1, 1, 0.01, 1, 89, 'Austin', '100 and below'),
#  (49, 'Alyson & Max', '78704', 30.24716, -97.782, 'Private room', 125, 2, 75, 0.65, 4, 364, 'Austin', '100 to 200'),
#  (50, 'Marcus', '78751', 30.31262, -97.72543, 'Entire home/apt', 109, 2, 338, 2.91, 1, 126, 'Austin', '100 to 200'),
#  (51, 'Sean', '78704', 30.26088, -97.77438, 'Entire home/apt', 97, 2, 139, 1.2, 14, 114, 'Austin', '100 and below'),
#  (52, 'Ford', '78703', 30.2809, -97.76065, 'Entire home/apt', 119, 30, 55, 0.47, 1, 89, 'Austin', '100 to 200'),
#  (53, 'Beau', '78704', 30.24936, -97.75904, 'Entire home/apt', 150, 2, 78, 0.67, 1, 266, 'Austin', '100 to 200'),
#  (54, 'Shawn', '78702', 30.26071, -97.73258, 'Entire home/apt', 225, 4, 34, 0.31, 2, 0, 'Austin', '200 to 400'),
#  (55, 'Merlyn', '78703', 30.28408, -97.76828, 'Entire home/apt', 150, 30, 0, None, 1, 244, 'Austin', '100 to 200'),
#  (56, 'Kimberly', '78723', 30.30419, -97.68914, 'Entire home/apt', 400, 1, 3, 0.1, 1, 90, 'Austin', '200 to 400'),
#  (57, 'Michele', '78752', 30.32373, -97.71629, 'Private room', 50, 2, 180, 1.64, 1, 321, 'Austin', '100 and below'),
#  (58, 'Lucien', '78705', 30.29269, -97.74345, 'Entire home/apt', 81, 2, 16, 0.43, 2, 0, 'Austin', '100 and below'),
#  (59, 'Greg & Amanda', '78757', 30.35669, -97.72658, 'Entire home/apt', 329, 30, 116, 1.18, 12, 0, 'Austin', '200 to 400'),
#  (60, 'Mary', '78704', 30.24613, -97.74528, 'Entire home/apt', 70, 31, 128, 1.13, 2, 271, 'Austin', '100 and below'),
#  (61, 'Amanda (Marz, Nickname)', '78703', 30.28399, -97.77094, 'Entire home/apt', 80, 3, 7, 0.13, 3, 342, 'Austin', '100 and below'),
#  (62, 'Pete', '78751', 30.30326, -97.73057, 'Entire home/apt', 126, 5, 78, 0.74, 9, 297, 'Austin', '100 to 200'),
#  (63, 'Larry And Susan', '78751', 30.3022, -97.73013, 'Private room', 60, 30, 12, 0.11, 2, 260, 'Austin', '100 and below'),
#  (64, 'Julia', '78701', 30.27509, -97.74851, 'Entire home/apt', 259, 1, 2, 0.02, 3, 0, 'Austin', '200 to 400'),
#  (65, 'Morrie And Rachel', '78736', 30.24395, -98.00244, 'Entire home/apt', 295, 3, 50, 2.15, 2, 0, 'Austin', '200 to 400'),
#  (66, 'Pete', '78751', 30.30226, -97.73143, 'Entire home/apt', 142, 5, 71, 0.65, 9, 299, 'Austin', '100 to 200'),
#  (67, 'Pete', '78751', 30.30242, -97.72954, 'Entire home/apt', 126, 5, 69, 0.63, 9, 294, 'Austin', '100 to 200'),
#  (68, 'Epiphany', '78702', 30.25582, -97.72709, 'Entire home/apt', 97, 1, 442, 4.02, 1, 26, 'Austin', '100 and below'),
#  (69, 'Dan', '78705', 30.30219, -97.74143, 'Entire home/apt', 100, 3, 198, 2.08, 1, 331, 'Austin', '100 and below'),
#  (70, 'Scott', '78704', 30.2515, -97.78206, 'Entire home/apt', 373, 3, 14, 0.13, 1, 364, 'Austin', '200 to 400'),
#  (71, 'Keith', '78732', 30.41813, -97.88915, 'Entire home/apt', 94, 90, 33, 0.31, 3, 129, 'Austin', '100 and below'),
#  (72, 'Lis', '78704', 30.2521, -97.78382, 'Entire home/apt', 442, 3, 11, 0.11, 1, 278, 'Austin', '400 or more'),
#  (73, 'Particular Properties', '78704', 30.24154, -97.76121, 'Entire home/apt', 79, 2, 363, 3.25, 2, 199, 'Austin', '100 and below'),
#  (74, 'Marnie', '78746', 30.27728, -97.79113, 'Entire home/apt', 800, 3, 7, 0.06, 1, 362, 'Austin', '400 or more'),
#  (75, 'Isabel', '78745', 30.19318, -97.82095, 'Entire home/apt', 75, 3, 10, 0.46, 1, 0, 'Austin', '100 and below'),
#  (76, 'Jenny', '78752', 30.33107, -97.7142, 'Entire home/apt', 265, 2, 311, 2.84, 1, 330, 'Austin', '200 to 400'),
#  (77, 'John', '78704', 30.25784, -97.76114, 'Entire home/apt', 270, 3, 242, 3.29, 1, 179, 'Austin', '200 to 400'),
#  (78, 'Lori', '78704', 30.25836, -97.76723, 'Entire home/apt', 750, 2, 29, 0.32, 1, 365, 'Austin', '400 or more'),
#  (79, 'John', '78704', 30.24776, -97.74527, 'Entire home/apt', 65, 1, 744, 6.8, 2, 312, 'Austin', '100 and below'),
#  (80, 'Tracy', '78703', 30.27571, -97.75819, 'Private room', 175, 3, 10, 0.34, 1, 87, 'Austin', '100 to 200'),
#  (81, 'Merri Gale & Donald', '78741', 30.24594, -97.7313, 'Entire home/apt', 135, 2, 142, 1.31, 1, 177, 'Austin', '100 to 200'),
#  (82, 'Suzanne', '78702', 30.2635, -97.70097, 'Entire home/apt', 213, 2, 85, 1.07, 1, 90, 'Austin', '200 to 400'),
#  (83, 'T.M.', '78722', 30.28913, -97.71844, 'Entire home/apt', 99, 2, 128, 1.21, 1, 0, 'Austin', '100 and below'),
#  (84, 'Kalu', '78704', 30.24503, -97.74531, 'Entire home/apt', 250, 2, 10, 1.46, 1, 0, 'Austin', '200 to 400'),
#  (85, 'Kris', '78704', 30.25321, -97.77306, 'Entire home/apt', 74, 1, 21, 0.2, 1, 105, 'Austin', '100 and below'),
#  (86, 'Lyon', '78702', 30.25733, -97.73157, 'Entire home/apt', 185, 4, 30, 0.29, 3, 361, 'Austin', '100 to 200'),
#  (87, 'Lyon', '78702', 30.25883, -97.73089, 'Entire home/apt', 500, 4, 53, 0.49, 3, 361, 'Austin', '400 or more'),
#  (88, 'David And Kristy', '78751', 30.30788, -97.72679, 'Entire home/apt', 105, 28, 105, 0.96, 1, 292, 'Austin', '100 to 200'),
#  (89, 'Hunter', '78704', 30.24846, -97.75077, 'Entire home/apt', 171, 1, 182, 1.76, 5, 22, 'Austin', '100 to 200'),
#  (90, 'Sharon', '78728', 30.45831, -97.68722, 'Entire home/apt', 350, 4, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (91, 'Pete', '78751', 30.30271, -97.73123, 'Entire home/apt', 165, 5, 73, 0.69, 9, 273, 'Austin', '100 to 200'),
#  (92, 'Elizabeth', '78702', 30.25409, -97.72566, 'Entire home/apt', 135, 1, 51, 0.47, 2, 0, 'Austin', '100 to 200'),
#  (93, 'Kerry', '78704', 30.25368, -97.7567, 'Entire home/apt', 150, 2, 108, 1.7, 4, 217, 'Austin', '100 to 200'),
#  (94, 'Elizabeth', '78702', 30.25426, -97.72431, 'Entire home/apt', 29, 1, 459, 4.4, 2, 43, 'Austin', '100 and below'),
#  (95, 'Gloria', '78723', 30.3034, -97.68496, 'Entire home/apt', 175, 2, 1, 0.01, 1, 0, 'Austin', '100 to 200'),
#  (96, 'Caitlin', '78702', 30.25434, -97.72825, 'Entire home/apt', 137, 2, 66, 0.64, 2, 18, 'Austin', '100 to 200'),
#  (97, 'Kelsey', '78704', 30.25309, -97.77375, 'Entire home/apt', 350, 3, 30, 1.45, 1, 0, 'Austin', '200 to 400'),
#  (98, 'Michael', '78703', 30.28281, -97.76417, 'Entire home/apt', 628, 2, 56, 0.52, 4, 365, 'Austin', '400 or more'),
#  (99, 'Teresa', '78758', 30.36774, -97.7078, 'Entire home/apt', 62, 30, 23, 0.22, 1, 0, 'Austin', '100 and below'),
#  (100, 'Dallas', '78704', 30.23223, -97.74579, 'Entire home/apt', 201, 2, 243, 2.34, 17, 342, 'Austin', '200 to 400'),
#  (101, 'Joseph', '78745', 30.18844, -97.78975, 'Entire home/apt', 185, 30, 54, 0.52, 2, 333, 'Austin', '100 to 200'),
#  (102, 'Veronica', '78704', 30.25721, -97.75563, 'Entire home/apt', 130, 2, 332, 3.18, 1, 364, 'Austin', '100 to 200'),
#  (103, 'Chris', '78702', 30.27448, -97.72692, 'Private room', 60, 2, 259, 2.45, 1, 365, 'Austin', '100 and below'),
#  (104, "Jim O'", '78745', 30.20948, -97.76969, 'Entire home/apt', 66, 2, 111, 1.05, 14, 361, 'Austin', '100 and below'),
#  (105, 'Alyson & Max', '78704', 30.25191, -97.78116, 'Private room', 225, 2, 22, 0.21, 4, 89, 'Austin', '200 to 400'),
#  (106, 'Denise', '78730', 30.35672, -97.79621, 'Entire home/apt', 350, 4, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (107, 'John', '78745', 30.2135, -97.7809, 'Entire home/apt', 600, 3, 2, 0.02, 1, 365, 'Austin', '400 or more'),
#  (108, 'Gretchen', '78704', 30.25431, -97.75578, 'Entire home/apt', 400, 3, 9, 0.09, 1, 0, 'Austin', '200 to 400'),
#  (109, 'Kristen', '78702', 30.26585, -97.73328, 'Entire home/apt', 457, 1, 231, 2.23, 12, 340, 'Austin', '400 or more'),
#  (110, 'Jessica & Jeremy', '78702', 30.25536, -97.72855, 'Entire home/apt', 694, 4, 2, 0.03, 1, 0, 'Austin', '400 or more'),
#  (111, 'Gary', '78724', 30.28413, -97.64927, 'Entire home/apt', 191, 2, 82, 0.79, 2, 134, 'Austin', '100 to 200'),
#  (112, 'Stephanie', '78753', 30.35229, -97.69454, 'Entire home/apt', 625, 4, 4, 0.04, 1, 365, 'Austin', '400 or more'),
#  (113, 'Liz', '78704', 30.25407, -97.77818, 'Entire home/apt', 750, 2, 1, 0.04, 1, 95, 'Austin', '400 or more'),
#  (114, 'Sara', '78702', 30.27752, -97.71919, 'Entire home/apt', 98, 1, 431, 4.13, 2, 0, 'Austin', '100 and below'),
#  (115, 'James', '78704', 30.2509, -97.78843, 'Entire home/apt', 500, 1, 13, 0.14, 1, 0, 'Austin', '400 or more'),
#  (116, 'Leslie And Dylan', '78702', 30.26833, -97.71708, 'Entire home/apt', 240, 4, 47, 0.45, 1, 0, 'Austin', '200 to 400'),
#  (117, 'Erik & Crystal', '78701', 30.26778, -97.74563, 'Entire home/apt', 178, 1, 370, 3.85, 1, 0, 'Austin', '100 to 200'),
#  (118, 'Mark', '78705', 30.30044, -97.73687, 'Entire home/apt', 80, 30, 0, None, 2, 365, 'Austin', '100 and below'),
#  (119, 'Abbie & Brian', '78704', 30.24583, -97.75472, 'Entire home/apt', 699, 3, 36, 0.35, 1, 48, 'Austin', '400 or more'),
#  (120, 'Lionel & Beth', '78756', 30.32631, -97.7425, 'Entire home/apt', 95, 29, 5, 0.05, 1, 165, 'Austin', '100 and below'),
#  (121, 'Carol', '78751', 30.31218, -97.71745, 'Entire home/apt', 179, 2, 2, 0.02, 2, 109, 'Austin', '100 to 200'),
#  (122, 'Janet', '78746', 30.3024, -97.80719, 'Entire home/apt', 495, 3, 6, 0.06, 1, 322, 'Austin', '400 or more'),
#  (123, 'Angel', '78702', 30.27235, -97.72514, 'Private room', 61, 2, 472, 4.56, 5, 357, 'Austin', '100 and below'),
#  (124, 'Janet', '78729', 30.45096, -97.76467, 'Private room', 111, 2, 15, 0.14, 1, 365, 'Austin', '100 to 200'),
#  (125, 'Sandra', '78725', 30.23911, -97.58625, 'Private room', 100, 2, 0, None, 1, 365, 'Austin', '100 and below'),
#  (126, 'Ashly', '78754', 30.36875, -97.65554, 'Private room', 109, 1, 0, None, 1, 0, 'Austin', '100 to 200'),
#  (127, 'Virginia', '78703', 30.31293, -97.76659, 'Entire home/apt', 246, 3, 126, 1.31, 1, 289, 'Austin', '200 to 400'),
#  (128, 'Larry And Joanna', '78702', 30.27508, -97.72995, 'Private room', 68, 1, 140, 1.35, 1, 142, 'Austin', '100 and below'),
#  (129, 'D', '78741', 30.24468, -97.72442, 'Entire home/apt', 250, 1, 2, 0.02, 1, 0, 'Austin', '200 to 400'),
#  (130, 'Stephen', '78749', 30.20621, -97.85577, 'Entire home/apt', 808, 2, 34, 0.33, 2, 351, 'Austin', '400 or more'),
#  (131, 'Carolyn', '78759', 30.42198, -97.76717, 'Private room', 80, 32, 33, 0.32, 1, 83, 'Austin', '100 and below'),
#  (132, 'Jessica', '78702', 30.256, -97.72595, 'Entire home/apt', 175, 2, 190, 1.83, 1, 171, 'Austin', '100 to 200'),
#  (133, 'Linda And Lia', '78702', 30.27374, -97.71887, 'Private room', 85, 2, 69, 0.67, 2, 259, 'Austin', '100 and below'),
#  (134, 'Shanti', '78746', 30.261, -97.79197, 'Entire home/apt', 400, 4, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (135, 'Shelley', '78757', 30.33108, -97.72586, 'Entire home/apt', 50, 30, 15, 0.15, 2, 91, 'Austin', '100 and below'),
#  (136, 'Glory', '78735', 30.25264, -97.87296, 'Entire home/apt', 300, 3, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (137, 'Luke And Rachel', '78702', 30.26496, -97.71496, 'Entire home/apt', 750, 4, 125, 1.2, 1, 0, 'Austin', '400 or more'),
#  (138, 'Julie', '78704', 30.24754, -97.75855, 'Private room', 110, 2, 68, 0.66, 1, 262, 'Austin', '100 to 200'),
#  (139, 'Teresa', '78759', 30.41699, -97.7544, 'Private room', 34, 31, 3, 0.12, 1, 258, 'Austin', '100 and below'),
#  (140, 'Gabrielle', '78702', 30.2582, -97.72019, 'Entire home/apt', 400, 3, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (141, 'Rachel', '78721', 30.26912, -97.68767, 'Entire home/apt', 99, 1, 243, 2.35, 1, 260, 'Austin', '100 and below'),
#  (142, 'Darcy', '78702', 30.27452, -97.72249, 'Entire home/apt', 35, 30, 22, 0.21, 1, 300, 'Austin', '100 and below'),
#  (143, 'Adam', '78704', 30.25035, -97.75722, 'Entire home/apt', 370, 3, 36, 0.45, 1, 331, 'Austin', '200 to 400'),
#  (144, 'Cecily', '78701', 30.27105, -97.74933, 'Entire home/apt', 299, 3, 8, 0.08, 2, 0, 'Austin', '200 to 400'),
#  (145, 'Whitney', '78704', 30.24547, -97.74739, 'Entire home/apt', 210, 2, 70, 0.77, 1, 173, 'Austin', '200 to 400'),
#  (146, 'Gigi', '78704', 30.24836, -97.76186, 'Entire home/apt', 161, 3, 207, 2.03, 3, 349, 'Austin', '100 to 200'),
#  (147, 'Janine', '78702', 30.25462, -97.72125, 'Entire home/apt', 750, 2, 8, 0.09, 1, 365, 'Austin', '400 or more'),
#  (148, 'Doug & Savanna', '78702', 30.26487, -97.71649, 'Entire home/apt', 125, 2, 29, 0.28, 1, 0, 'Austin', '100 to 200'),
#  (149, 'Charm', '78704', 30.23618, -97.74439, 'Entire home/apt', 430, 1, 36, 0.35, 2, 179, 'Austin', '400 or more'),
#  (150, 'Amber', '78704', 30.2521, -97.76163, 'Entire home/apt', 643, 5, 1, 0.01, 1, 0, 'Austin', '400 or more'),
#  (151, 'Meredith', '78702', 30.27875, -97.72359, 'Entire home/apt', 118, 1, 594, 5.74, 5, 343, 'Austin', '100 to 200'),
#  (152, 'Cindie', '78703', 30.29933, -97.77637, 'Private room', 52, 1, 45, 0.53, 1, 0, 'Austin', '100 and below'),
#  (153, 'Julie', '78754', 30.33179, -97.64911, 'Private room', 75, 1, 0, None, 1, 0, 'Austin', '100 and below'),
#  (154, 'Jeannie', '78704', 30.23846, -97.74613, 'Entire home/apt', 58, 29, 6, 0.06, 2, 199, 'Austin', '100 and below'),
#  (155, 'Lara', '78704', 30.24336, -97.75152, 'Entire home/apt', 575, 3, 143, 1.8, 1, 269, 'Austin', '400 or more'),
#  (156, 'Mykel', '78746', 30.34442, -97.80005, 'Entire home/apt', 225, 3, 1, 0.01, 1, 0, 'Austin', '200 to 400'),
#  (157, 'Gigi', '78704', 30.24782, -97.76294, 'Entire home/apt', 128, 2, 297, 2.86, 3, 339, 'Austin', '100 to 200'),
#  (158, 'Sara', '78702', 30.25859, -97.72983, 'Entire home/apt', 630, 3, 5, 0.05, 1, 0, 'Austin', '400 or more'),
#  (159, 'Sarah', '78702', 30.26332, -97.72082, 'Entire home/apt', 1022, 3, 110, 1.06, 1, 362, 'Austin', '400 or more'),
#  (160, 'Mike', '78703', 30.28923, -97.7606, 'Entire home/apt', 248, 3, 11, 0.11, 1, 0, 'Austin', '200 to 400'),
#  (161, 'Scott', '78745', 30.22062, -97.77387, 'Entire home/apt', 110, 30, 18, 0.17, 1, 42, 'Austin', '100 to 200'),
#  (162, 'Jeffrey', '78704', 30.24803, -97.74556, 'Entire home/apt', 1000, 1, 3, 0.03, 1, 365, 'Austin', '400 or more'),
#  (163, 'Joan', '78704', 30.23928, -97.77907, 'Entire home/apt', 100, 1, 0, None, 1, 0, 'Austin', '100 and below'),
#  (164, 'An', '78703', 30.27927, -97.75422, 'Entire home/apt', 99, 2, 12, 0.12, 1, 0, 'Austin', '100 and below'),
#  (165, 'Trey', '78703', 30.30587, -97.77132, 'Entire home/apt', 1050, 30, 2, 0.02, 1, 0, 'Austin', '400 or more'),
#  (166, 'Jai', '78723', 30.30599, -97.69641, 'Entire home/apt', 300, 2, 1, 0.01, 1, 0, 'Austin', '200 to 400'),
#  (167, 'Varun', '78701', 30.2805, -97.74286, 'Entire home/apt', 428, 2, 9, 0.09, 1, 216, 'Austin', '400 or more'),
#  (168, 'David', '78704', 30.24981, -97.77782, 'Entire home/apt', 495, 2, 3, 0.03, 1, 0, 'Austin', '400 or more'),
#  (169, 'Renee', '78704', 30.2552, -97.76862, 'Entire home/apt', 189, 3, 224, 2.16, 2, 45, 'Austin', '100 to 200'),
#  (170, 'Monica', '78751', 30.31062, -97.7184, 'Private room', 100, 1, 178, 1.72, 1, 257, 'Austin', '100 and below'),
#  (171, 'Kathy', '78704', 30.22974, -97.76657, 'Entire home/apt', 800, 1, 0, None, 1, 0, 'Austin', '400 or more'),
#  (172, 'Chris', '78756', 30.31725, -97.74403, 'Entire home/apt', 625, 4, 0, None, 1, 365, 'Austin', '400 or more'),
#  (173, 'Robert', '78702', 30.2532, -97.72391, 'Entire home/apt', 500, 2, 110, 3.02, 1, 0, 'Austin', '400 or more'),
#  (174, 'Daniel', '78704', 30.25433, -97.77582, 'Entire home/apt', 71, 1, 237, 2.29, 1, 74, 'Austin', '100 and below'),
#  (175, 'Scott And Sally', '78704', 30.25756, -97.77102, 'Entire home/apt', 815, 4, 27, 0.34, 11, 190, 'Austin', '400 or more'),
#  (176, 'Adriana', '78703', 30.27407, -97.75345, 'Entire home/apt', 225, 5, 13, 0.14, 1, 0, 'Austin', '200 to 400'),
#  (177, 'Bruce', '78734', 30.39409, -97.91907, 'Hotel room', 210, 2, 1, 0.03, 1, 350, 'Austin', '200 to 400'),
#  (178, 'Scott And Sally', '78704', 30.25865, -97.76926, 'Entire home/apt', 305, 30, 81, 0.78, 11, 216, 'Austin', '200 to 400'),
#  (179, 'D.K.', '78702', 30.25917, -97.73425, 'Entire home/apt', 242, 2, 73, 0.7, 1, 38, 'Austin', '200 to 400'),
#  (180, 'Vacasa Texas', '78751', 30.30625, -97.72202, 'Entire home/apt', 132, 2, 160, 1.55, 28, 359, 'Austin', '100 to 200'),
#  (181, 'Alex', '78721', 30.26526, -97.6846, 'Entire home/apt', 120, 2, 94, 1.54, 1, 338, 'Austin', '100 to 200'),
#  (182, 'Caroline', '78751', 30.30676, -97.72635, 'Entire home/apt', 106, 3, 186, 1.79, 1, 0, 'Austin', '100 to 200'),
#  (183, 'John', '78703', 30.30665, -97.77151, 'Entire home/apt', 2150, 4, 1, 0.01, 1, 0, 'Austin', '400 or more'),
#  (184, 'Sarah', '78704', 30.25858, -97.75181, 'Entire home/apt', 650, 1, 0, None, 1, 0, 'Austin', '400 or more'),
#  (185, "Jim O'", '78745', 30.20981, -97.77037, 'Entire home/apt', 15, 2, 19, 0.19, 14, 364, 'Austin', '100 and below'),
#  (186, 'Susan', '78704', 30.25374, -97.74519, 'Private room', 175, 2, 2, 0.02, 3, 0, 'Austin', '100 to 200'),
#  (187, 'Susan', '78704', 30.25226, -97.74438, 'Entire home/apt', 595, 3, 0, None, 3, 0, 'Austin', '400 or more'),
#  (188, 'Susan', '78704', 30.2524, -97.74437, 'Entire home/apt', 575, 3, 3, 0.03, 3, 83, 'Austin', '400 or more'),
#  (189, 'Ernest', '78739', 30.16976, -97.86306, 'Entire home/apt', 1286, 3, 0, None, 1, 365, 'Austin', '400 or more'),
#  (190, 'Gigi', '78704', 30.24658, -97.7628, 'Entire home/apt', 88, 3, 24, 0.25, 3, 0, 'Austin', '100 and below'),
#  (191, 'Cynthia', '78704', 30.25909, -97.756, 'Entire home/apt', 115, 1, 293, 3.03, 1, 355, 'Austin', '100 to 200'),
#  (192, 'Benjamin', '78704', 30.23944, -97.7535, 'Private room', 47, 1, 52, 0.55, 2, 0, 'Austin', '100 and below'),
#  (193, 'Susie & Eoin', '78704', 30.24035, -97.7522, 'Entire home/apt', 129, 30, 21, 0.23, 1, 268, 'Austin', '100 to 200'),
#  (194, 'Melanie', '78731', 30.33945, -97.76182, 'Entire home/apt', 695, 30, 10, 0.81, 2, 0, 'Austin', '400 or more'),
#  (195, 'Sean', '78704', 30.26083, -97.77521, 'Entire home/apt', 100, 2, 227, 2.25, 14, 15, 'Austin', '100 and below'),
#  (196, 'Cecily', '78701', 30.27132, -97.74777, 'Private room', 82, 2, 164, 1.61, 2, 89, 'Austin', '100 and below'),
#  (197, 'Gretchen', '78746', 30.2994, -97.79666, 'Entire home/apt', 329, 3, 83, 0.82, 1, 244, 'Austin', '200 to 400'),
#  (198, 'Nita', '78756', 30.32225, -97.7296, 'Entire home/apt', 95, 2, 65, 0.68, 1, 328, 'Austin', '100 and below'),
#  (199, 'Marit', '78704', 30.25201, -97.78184, 'Entire home/apt', 599, 2, 5, 0.06, 1, 365, 'Austin', '400 or more'),
#  (200, 'Amanda', '78704', 30.25774, -97.75158, 'Private room', 45, 30, 24, 0.24, 3, 205, 'Austin', '100 and below'),
#  (201, 'Jane', '78702', 30.2698, -97.72854, 'Entire home/apt', 139, 2, 88, 1.09, 1, 169, 'Austin', '100 to 200'),
#  (202, 'Michelle', '78704', 30.25282, -97.74596, 'Entire home/apt', 236, 2, 31, 0.66, 4, 352, 'Austin', '200 to 400'),
#  (203, 'Steve', '78733', 30.34467, -97.86235, 'Entire home/apt', 232, 2, 68, 0.92, 1, 1, 'Austin', '200 to 400'),
#  (204, 'Clint', '78745', 30.20841, -97.81879, 'Entire home/apt', 250, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (205, 'Rice', '78705', 30.29961, -97.73449, 'Entire home/apt', 110, 2, 93, 1.1, 1, 341, 'Austin', '100 to 200'),
#  (206, 'Alexis', '78701', 30.28004, -97.74563, 'Entire home/apt', 99, 2, 399, 3.97, 1, 98, 'Austin', '100 and below'),
#  (207, 'Kris', '78757', 30.33962, -97.73593, 'Entire home/apt', 121, 2, 66, 0.67, 1, 126, 'Austin', '100 to 200'),
#  (208, 'Amber', '78704', 30.26164, -97.76158, 'Entire home/apt', 99, 14, 450, 4.47, 2, 79, 'Austin', '100 and below'),
#  (209, 'Sheila', '78741', 30.22142, -97.73484, 'Entire home/apt', 48, 30, 126, 1.35, 1, 141, 'Austin', '100 and below'),
#  (210, 'John', '78704', 30.24945, -97.74613, 'Entire home/apt', 255, 3, 7, 0.08, 2, 0, 'Austin', '200 to 400'),
#  (211, 'Sharon', '78702', 30.27665, -97.71857, 'Private room', 100, 2, 25, 0.27, 1, 365, 'Austin', '100 and below'),
#  (212, 'Karen', '78704', 30.24921, -97.78566, 'Entire home/apt', 350, 2, 46, 0.47, 1, 341, 'Austin', '200 to 400'),
#  (213, 'Pamela', '78704', 30.25132, -97.79406, 'Private room', 55, 30, 1, 0.01, 1, 365, 'Austin', '100 and below'),
#  (214, 'Melissa', '78704', 30.24348, -97.74093, 'Private room', 105, 2, 12, 0.13, 2, 88, 'Austin', '100 to 200'),
#  (215, 'Margo', '78704', 30.25783, -97.76449, 'Entire home/apt', 98, 1, 367, 3.78, 1, 362, 'Austin', '100 and below'),
#  (216, 'Mary', '78704', 30.25656, -97.78681, 'Entire home/apt', 499, 30, 1, 0.01, 1, 16, 'Austin', '400 or more'),
#  (217, 'Andrew', '78704', 30.2466, -97.76628, 'Entire home/apt', 107, 2, 154, 1.58, 1, 246, 'Austin', '100 to 200'),
#  (218, 'Tracy', '78704', 30.24373, -97.75394, 'Entire home/apt', 393, 1, 38, 0.42, 2, 285, 'Austin', '200 to 400'),
#  (219, 'Alexis', '78757', 30.35994, -97.73144, 'Entire home/apt', 75, 30, 5, 0.06, 1, 259, 'Austin', '100 and below'),
#  (220, 'Joseph', '78745', 30.20283, -97.79705, 'Entire home/apt', 180, 30, 84, 0.88, 2, 292, 'Austin', '100 to 200'),
#  (221, 'Adam', '78723', 30.30267, -97.67915, 'Private room', 73, 1, 111, 1.13, 1, 329, 'Austin', '100 and below'),
#  (222, 'Simon', '78704', 30.2452, -97.76084, 'Entire home/apt', 95, 30, 47, 0.48, 2, 160, 'Austin', '100 and below'),
#  (223, 'Janet', '78722', 30.30086, -97.7152, 'Private room', 70, 2, 28, 0.29, 1, 365, 'Austin', '100 and below'),
#  (224, 'Jim', '78722', 30.29077, -97.71777, 'Entire home/apt', 55, 30, 16, 0.17, 2, 0, 'Austin', '100 and below'),
#  (225, 'Amy', '78703', 30.27634, -97.75923, 'Entire home/apt', 90, 2, 94, 0.95, 1, 252, 'Austin', '100 and below'),
#  (226, 'Flip', '78705', 30.28727, -97.75225, 'Entire home/apt', 117, 30, 29, 0.3, 2, 296, 'Austin', '100 to 200'),
#  (227, 'Amanda (Marz, Nickname)', '78703', 30.28406, -97.7702, 'Private room', 60, 2, 0, None, 3, 346, 'Austin', '100 and below'),
#  (228, 'Crystal', '78702', 30.27191, -97.71989, 'Entire home/apt', 164, 1, 464, 4.74, 5, 309, 'Austin', '100 to 200'),
#  (229, 'Michelle', '78722', 30.28273, -97.71702, 'Entire home/apt', 164, 2, 293, 3.08, 1, 81, 'Austin', '100 to 200'),
#  (230, 'Tanner', '78731', 30.36007, -97.76109, 'Entire home/apt', 1800, 2, 9, 0.11, 1, 358, 'Austin', '400 or more'),
#  (231, 'Amanda (Marz, Nickname)', '78703', 30.28445, -97.77043, 'Entire home/apt', 91, 3, 5, 0.34, 3, 195, 'Austin', '100 and below'),
#  (232, 'Jaz', '78703', 30.27933, -97.75131, 'Entire home/apt', 190, 3, 11, 0.25, 1, 0, 'Austin', '100 to 200'),
#  (233, 'Tracey', '78704', 30.24972, -97.73887, 'Entire home/apt', 649, 2, 26, 0.28, 1, 350, 'Austin', '400 or more'),
#  (234, 'Simon', '78733', 30.34245, -97.86974, 'Entire home/apt', 75, 15, 64, 0.66, 2, 42, 'Austin', '100 and below'),
#  (235, 'Kathleen', '78704', 30.24453, -97.73892, 'Entire home/apt', 75, 2, 651, 6.68, 2, 276, 'Austin', '100 and below'),
#  (236, 'Perry', '78701', 30.27664, -97.7498, 'Entire home/apt', 899, 3, 1, 0.01, 1, 365, 'Austin', '400 or more'),
#  (237, 'Fred And Kellner', '78702', 30.25739, -97.72915, 'Entire home/apt', 219, 3, 103, 1.11, 1, 310, 'Austin', '200 to 400'),
#  (238, 'Gisela', '78704', 30.25118, -97.77234, 'Entire home/apt', 139, 2, 132, 1.37, 1, 179, 'Austin', '100 to 200'),
#  (239, 'Mary', '78757', 30.33514, -97.72913, 'Entire home/apt', 80, 30, 18, 0.19, 2, 163, 'Austin', '100 and below'),
#  (240, 'Brandon', '78703', 30.26866, -97.75176, 'Entire home/apt', 493, 5, 2, 0.02, 1, 0, 'Austin', '400 or more'),
#  (241, 'Lata', '78733', 30.34929, -97.85596, 'Private room', 68, 2, 165, 1.77, 2, 154, 'Austin', '100 and below'),
#  (242, 'Geoff', '78704', 30.24198, -97.77677, 'Entire home/apt', 650, 3, 21, 0.22, 1, 0, 'Austin', '400 or more'),
#  (243, 'Marjorie', '78704', 30.25678, -97.78016, 'Entire home/apt', 800, 3, 74, 0.81, 1, 362, 'Austin', '400 or more'),
#  (244, 'John & Carol', '78704', 30.24649, -97.75696, 'Entire home/apt', 249, 2, 156, 1.62, 1, 0, 'Austin', '200 to 400'),
#  (245, 'Lindsay', '78704', 30.23904, -97.74569, 'Entire home/apt', 743, 1, 90, 0.94, 2, 254, 'Austin', '400 or more'),
#  (246, 'Jose', '78745', 30.22437, -97.81647, 'Entire home/apt', 1499, 3, 56, 0.58, 1, 362, 'Austin', '400 or more'),
#  (247, 'Chad', '78746', 30.27482, -97.79646, 'Entire home/apt', 2000, 3, 0, None, 1, 0, 'Austin', '400 or more'),
#  (248, 'Laura', '78703', 30.2803, -97.75612, 'Entire home/apt', 821, 2, 26, 0.28, 1, 361, 'Austin', '400 or more'),
#  (249, "Jim O'", '78745', 30.21002, -97.77059, 'Entire home/apt', 15, 2, 17, 0.18, 14, 364, 'Austin', '100 and below'),
#  (250, "Jim O'", '78745', 30.21077, -97.77134, 'Entire home/apt', 15, 2, 68, 0.74, 14, 365, 'Austin', '100 and below'),
#  (251, "Jim O'", '78745', 30.2084, -97.76878, 'Entire home/apt', 15, 2, 14, 0.15, 14, 364, 'Austin', '100 and below'),
#  (252, 'Meaghan', '78731', 30.35037, -97.75921, 'Entire home/apt', 275, 2, 67, 0.73, 1, 178, 'Austin', '200 to 400'),
#  (253, 'Garret', '78704', 30.23628, -97.75248, 'Entire home/apt', 54, 30, 61, 0.63, 2, 273, 'Austin', '100 and below'),
#  (254, 'Alana', '78704', 30.24317, -97.74173, 'Entire home/apt', 545, 2, 0, None, 1, 0, 'Austin', '400 or more'),
#  (255, 'Ryan', '78704', 30.25689, -97.74658, 'Private room', 250, 3, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (256, 'Katherine', '78731', 30.31044, -97.75424, 'Entire home/apt', 154, 3, 38, 0.4, 3, 92, 'Austin', '100 to 200'),
#  (257, 'David', '78745', 30.19454, -97.78279, 'Entire home/apt', 400, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (258, 'Sabrina', '78703', 30.28116, -97.76067, 'Entire home/apt', 225, 2, 9, 0.09, 1, 0, 'Austin', '200 to 400'),
#  (259, 'David', '78759', 30.37253, -97.74474, 'Entire home/apt', 1250, 2, 0, None, 1, 0, 'Austin', '400 or more'),
#  (260, 'Elizabeth & Mike', '78705', 30.30051, -97.74043, 'Entire home/apt', 228, 2, 142, 1.55, 1, 0, 'Austin', '200 to 400'),
#  (261, 'Whitney', '78704', 30.24758, -97.7384, 'Entire home/apt', 232, 3, 31, 0.39, 1, 362, 'Austin', '200 to 400'),
#  (262, 'Courtney', '78704', 30.2307, -97.76556, 'Private room', 300, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (263, 'Larry', '78704', 30.23573, -97.76233, 'Entire home/apt', 257, 3, 175, 1.88, 1, 277, 'Austin', '200 to 400'),
#  (264, 'Leah', '78703', 30.29352, -97.77608, 'Entire home/apt', 1200, 3, 11, 0.12, 1, 276, 'Austin', '400 or more'),
#  (265, 'Amy', '78741', 30.24439, -97.72929, 'Entire home/apt', 135, 2, 22, 0.23, 1, 258, 'Austin', '100 to 200'),
#  (266, 'Bill', '78704', 30.24646, -97.74738, 'Entire home/apt', 153, 1, 592, 6.18, 3, 313, 'Austin', '100 to 200'),
#  (267, 'Brent', '78703', 30.28251, -97.77571, 'Entire home/apt', 2250, 5, 0, None, 1, 0, 'Austin', '400 or more'),
#  (268, 'Nadia', '78704', 30.24186, -97.77858, 'Entire home/apt', 233, 5, 5, 0.07, 1, 0, 'Austin', '200 to 400'),
#  (269, 'Ken', '78734', 30.39968, -97.91422, 'Entire home/apt', 1100, 1, 0, None, 1, 260, 'Austin', '400 or more'),
#  (270, 'Mandy', '78704', 30.23501, -97.78033, 'Entire home/apt', 500, 3, 0, None, 1, 0, 'Austin', '400 or more'),
#  (271, 'Susan', '78704', 30.24152, -97.76465, 'Entire home/apt', 89, 30, 81, 0.85, 1, 116, 'Austin', '100 and below'),
#  (272, 'Jake', '78754', 30.33496, -97.65115, 'Entire home/apt', 141, 1, 237, 2.46, 1, 306, 'Austin', '100 to 200'),
#  (273, 'Bridget', '78704', 30.25685, -97.76662, 'Entire home/apt', 1300, 2, 12, 0.13, 1, 365, 'Austin', '400 or more'),
#  (274, 'Mike', '78731', 30.32212, -97.75288, 'Entire home/apt', 66, 2, 98, 1.02, 1, 105, 'Austin', '100 and below'),
#  (275, 'David', '78741', 30.24629, -97.72886, 'Entire home/apt', 150, 2, 65, 0.73, 2, 322, 'Austin', '100 to 200'),
#  (276, 'Caren', '78723', 30.29444, -97.70331, 'Entire home/apt', 219, 2, 68, 0.74, 1, 240, 'Austin', '200 to 400'),
#  (277, 'Paola', '78702', 30.25124, -97.72618, 'Entire home/apt', 110, 30, 74, 0.81, 1, 333, 'Austin', '100 to 200'),
#  (278, 'Carol', '78704', 30.23923, -97.76319, 'Entire home/apt', 700, 4, 8, 0.1, 1, 0, 'Austin', '400 or more'),
#  (279, 'Arnie', '78704', 30.24347, -97.75295, 'Entire home/apt', 900, 3, 18, 0.25, 1, 105, 'Austin', '400 or more'),
#  (280, 'Justin&Becca', '78702', 30.2707, -97.72865, 'Entire home/apt', 679, 2, 227, 2.36, 2, 320, 'Austin', '400 or more'),
#  (281, 'Deena', '78722', 30.28457, -97.71333, 'Entire home/apt', 128, 3, 175, 2.61, 1, 5, 'Austin', '100 to 200'),
#  (282, 'Catherine', '78738', 30.32518, -97.97659, 'Entire home/apt', 1200, 3, 0, None, 1, 365, 'Austin', '400 or more'),
#  (283, 'Tami', '78745', 30.18757, -97.79019, 'Entire home/apt', 375, 3, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (284, 'Laura', '78727', 30.41456, -97.72319, 'Private room', 68, 30, 13, 0.15, 1, 352, 'Austin', '100 and below'),
#  (285, 'Robert', '78751', 30.31197, -97.72955, 'Entire home/apt', 329, 3, 74, 0.81, 2, 0, 'Austin', '200 to 400'),
#  (286, 'Susanna', '78704', 30.24437, -97.77435, 'Private room', 125, 30, 3, 0.04, 1, 365, 'Austin', '100 to 200'),
#  (287, 'James', '78741', 30.22569, -97.74008, 'Entire home/apt', 1250, 1, 0, None, 2, 365, 'Austin', '400 or more'),
#  (288, 'James', '78741', 30.22722, -97.74057, 'Entire home/apt', 1000, 3, 0, None, 2, 365, 'Austin', '400 or more'),
#  (289, 'Scott And Sally', '78704', 30.25806, -97.77089, 'Entire home/apt', 159, 5, 62, 0.68, 11, 223, 'Austin', '100 to 200'),
#  (290, 'Phillip', '78703', 30.27875, -97.75517, 'Entire home/apt', 160, 3, 88, 0.92, 1, 346, 'Austin', '100 to 200'),
#  (291, 'James', '78702', 30.2702, -97.72862, 'Entire home/apt', 200, 5, 24, 0.26, 1, 352, 'Austin', '100 to 200'),
#  (292, 'Greg & Amanda', '78757', 30.3605, -97.7255, 'Entire home/apt', 299, 30, 128, 1.66, 12, 0, 'Austin', '200 to 400'),
#  (293, 'James', '78704', 30.24354, -97.74737, 'Entire home/apt', 70, 30, 25, 0.27, 1, 335, 'Austin', '100 and below'),
#  (294, 'Gabe', '78701', 30.26731, -97.74613, 'Entire home/apt', 200, 90, 0, None, 2, 244, 'Austin', '100 to 200'),
#  (295, 'Mandi', '78704', 30.2466, -97.78334, 'Entire home/apt', 1000, 7, 7, 0.08, 1, 364, 'Austin', '400 or more'),
#  (296, 'Stan', '78703', 30.27829, -97.75604, 'Entire home/apt', 652, 2, 130, 1.42, 1, 359, 'Austin', '400 or more'),
#  (297, 'Mary K.', '78703', 30.29604, -97.77188, 'Entire home/apt', 1999, 3, 1, 0.01, 1, 365, 'Austin', '400 or more'),
#  (298, 'Karen', '78745', 30.21405, -97.81604, 'Private room', 106, 1, 0, None, 1, 365, 'Austin', '100 to 200'),
#  (299, 'Carolyn', '78756', 30.32255, -97.73869, 'Entire home/apt', 240, 1, 135, 3.22, 1, 260, 'Austin', '200 to 400'),
#  (300, 'Daniel', '78745', 30.22356, -97.7843, 'Private room', 100, 1, 7, 0.12, 1, 0, 'Austin', '100 and below'),
#  (301, 'Blaine & Rachel', '78741', 30.2305, -97.73961, 'Entire home/apt', 400, 1, 17, 0.19, 1, 365, 'Austin', '200 to 400'),
#  (302, 'Rick', '78722', 30.28593, -97.7208, 'Entire home/apt', 350, 3, 1, 0.01, 1, 365, 'Austin', '200 to 400'),
#  (303, 'David', '78741', 30.23895, -97.71176, 'Private room', 265, 1, 2, 0.02, 1, 365, 'Austin', '200 to 400'),
#  (304, 'Patrick', '78731', 30.34368, -97.76246, 'Entire home/apt', 1385, 2, 13, 0.16, 1, 362, 'Austin', '400 or more'),
#  (305, 'John & Tina', '78704', 30.24373, -97.74025, 'Entire home/apt', 795, 2, 59, 0.64, 1, 260, 'Austin', '400 or more'),
#  (306, 'Austin', '78701', 30.26528, -97.74062, 'Entire home/apt', 143, 180, 162, 1.73, 14, 40, 'Austin', '100 to 200'),
#  (307, 'Katy & Rick', '78704', 30.24778, -97.76287, 'Entire home/apt', 386, 2, 62, 0.78, 1, 260, 'Austin', '200 to 400'),
#  (308, 'Edward "Jack"', '78752', 30.3253, -97.6814, 'Private room', 125, 1, 0, None, 1, 365, 'Austin', '100 to 200'),
#  (309, 'Alyson & Max', '78704', 30.25392, -97.78091, 'Entire home/apt', 250, 1, 1, 0.05, 4, 44, 'Austin', '200 to 400'),
#  (310, 'Jana', '78704', 30.23307, -97.76086, 'Entire home/apt', 82, 2, 117, 1.26, 2, 292, 'Austin', '100 and below'),
#  (311, 'Julia', '78701', 30.27485, -97.74969, 'Entire home/apt', 260, 1, 7, 0.26, 3, 0, 'Austin', '200 to 400'),
#  (312, 'Pete', '78751', 30.30212, -97.72901, 'Entire home/apt', 102, 5, 51, 0.55, 9, 308, 'Austin', '100 to 200'),
#  (313, 'Moya', '78704', 30.25243, -97.77387, 'Entire home/apt', 1125, 3, 60, 0.63, 2, 331, 'Austin', '400 or more'),
#  (314, 'Nancy', '78722', 30.28557, -97.72051, 'Private room', 60, 2, 175, 1.91, 1, 261, 'Austin', '100 and below'),
#  (315, 'Katherine', '78726', 30.4443, -97.82519, 'Entire home/apt', 215, 3, 31, 0.58, 3, 154, 'Austin', '200 to 400'),
#  (316, 'Carmen', '78741', 30.2429, -97.72577, 'Private room', 185, 3, 10, 1.05, 1, 0, 'Austin', '100 to 200'),
#  (317, 'Sandra', '78704', 30.24597, -97.78038, 'Private room', 60, 1, 0, None, 1, 365, 'Austin', '100 and below'),
#  (318, 'Tina', '78704', 30.25262, -97.77083, 'Entire home/apt', 151, 2, 177, 1.9, 1, 291, 'Austin', '100 to 200'),
#  (319, 'Mollie', '78702', 30.26348, -97.7202, 'Entire home/apt', 150, 2, 75, 0.82, 1, 32, 'Austin', '100 to 200'),
#  (320, 'Abby', '78701', 30.27092, -97.74683, 'Entire home/apt', 100, 30, 5, 0.06, 1, 297, 'Austin', '100 and below'),
#  (321, 'Peter', '78756', 30.33193, -97.74269, 'Entire home/apt', 85, 30, 4, 0.06, 1, 79, 'Austin', '100 and below'),
#  (322, 'Francis', '78702', 30.25548, -97.7317, 'Entire home/apt', 375, 2, 6, 0.07, 1, 364, 'Austin', '200 to 400'),
#  (323, 'Amenity', '78702', 30.27651, -97.71919, 'Entire home/apt', 500, 2, 3, 0.03, 1, 0, 'Austin', '400 or more'),
#  (324, 'Troy', '78731', 30.32056, -97.7495, 'Private room', 98, 30, 168, 1.84, 1, 177, 'Austin', '100 and below'),
#  (325, 'Angel', '78702', 30.27204, -97.72384, 'Private room', 61, 2, 311, 3.36, 5, 363, 'Austin', '100 and below'),
#  (326, 'Susan', '78704', 30.24575, -97.748, 'Entire home/apt', 149, 2, 15, 0.25, 1, 133, 'Austin', '100 to 200'),
#  (327, 'Matt & Ali', '78703', 30.29328, -97.7684, 'Entire home/apt', 250, 30, 1, 0.01, 1, 0, 'Austin', '200 to 400'),
#  (328, 'Roman', '78702', 30.25326, -97.72617, 'Entire home/apt', 92, 2, 160, 2.24, 2, 112, 'Austin', '100 and below'),
#  (329, 'Amy', '78704', 30.2601, -97.76518, 'Entire home/apt', 1800, 3, 3, 0.04, 2, 173, 'Austin', '400 or more'),
#  (330, 'Kathy', '78704', 30.25266, -97.78441, 'Entire home/apt', 495, 2, 6, 0.07, 1, 0, 'Austin', '400 or more'),
#  (331, 'Dan & Erin', '78704', 30.24617, -97.76967, 'Entire home/apt', 103, 2, 145, 1.58, 1, 350, 'Austin', '100 to 200'),
#  (332, 'Paprika', '78702', 30.25268, -97.72162, 'Entire home/apt', 205, 2, 46, 0.83, 3, 2, 'Austin', '200 to 400'),
#  (333, 'Garret', '78704', 30.23429, -97.75383, 'Entire home/apt', 44, 30, 49, 0.54, 2, 260, 'Austin', '100 and below'),
#  (334, 'Kristin', '78702', 30.28087, -97.70546, 'Entire home/apt', 600, 3, 6, 0.07, 1, 0, 'Austin', '400 or more'),
#  (335, 'Leigh', '78723', 30.2936, -97.70568, 'Entire home/apt', 775, 5, 0, None, 1, 365, 'Austin', '400 or more'),
#  (336, 'David', '78702', 30.26069, -97.72331, 'Entire home/apt', 707, 1, 190, 2.08, 2, 358, 'Austin', '400 or more'),
#  (337, 'Olivia', '78702', 30.27961, -97.71591, 'Entire home/apt', 95, 10, 183, 2.0, 3, 97, 'Austin', '100 and below'),
#  (338, 'Bill', '78704', 30.24684, -97.7446, 'Entire home/apt', 495, 3, 9, 0.11, 1, 278, 'Austin', '400 or more'),
#  (339, 'Valentina', '78704', 30.2612, -97.76586, 'Entire home/apt', 116, 2, 39, 0.43, 2, 323, 'Austin', '100 to 200'),
#  (340, 'Salvador', '78705', 30.29938, -97.74284, 'Private room', 375, 1, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (341, 'Mary', '78704', 30.25063, -97.76887, 'Entire home/apt', 114, 3, 324, 3.51, 5, 92, 'Austin', '100 to 200'),
#  (342, 'Ishrat', '78702', 30.2672, -97.71609, 'Entire home/apt', 300, 2, 11, 0.12, 2, 169, 'Austin', '200 to 400'),
#  (343, 'Kindal', '78704', 30.23936, -97.78139, 'Entire home/apt', 350, 5, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (344, 'Kerstin', '78702', 30.25526, -97.73167, 'Entire home/apt', 425, 3, 2, 0.02, 1, 365, 'Austin', '400 or more'),
#  (345, 'Kevin', '78757', 30.3614, -97.71967, 'Entire home/apt', 68, 2, 71, 3.42, 1, 23, 'Austin', '100 and below'),
#  (346, 'Ryan', '78701', 30.26595, -97.74144, 'Entire home/apt', 145, 2, 219, 2.37, 31, 331, 'Austin', '100 to 200'),
#  (347, 'Laura', '78704', 30.2358, -97.77793, 'Entire home/apt', 111, 2, 234, 2.94, 2, 322, 'Austin', '100 to 200'),
#  (348, 'Matt', '78751', 30.31505, -97.73248, 'Entire home/apt', 480, 2, 0, None, 1, 365, 'Austin', '400 or more'),
#  (349, 'Lauren & Andrew', '78753', 30.39472, -97.66879, 'Private room', 164, 1, 0, None, 1, 365, 'Austin', '100 to 200'),
#  (350, 'Michael', '78723', 30.31635, -97.68109, 'Private room', 225, 5, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (351, 'Jim', '78753', 30.37743, -97.68401, 'Entire home/apt', 400, 1, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (352, 'Ryan', '78749', 30.2253, -97.86655, 'Private room', 5021, 3, 2, 0.02, 1, 0, 'Austin', '400 or more'),
#  (353, 'Niles', '78746', 30.34527, -97.79186, 'Entire home/apt', 1000, 4, 57, 0.67, 1, 102, 'Austin', '400 or more'),
#  (354, 'Matthew', '78741', 30.23988, -97.7335, 'Entire home/apt', 855, 3, 4, 0.04, 1, 365, 'Austin', '400 or more'),
#  (355, 'Lauren', '78703', 30.27617, -97.76189, 'Entire home/apt', 800, 5, 0, None, 1, 365, 'Austin', '400 or more'),
#  (356, 'Ken', '78702', 30.25481, -97.7356, 'Entire home/apt', 250, 4, 21, 0.23, 1, 0, 'Austin', '200 to 400'),
#  (357, 'Susie', '78704', 30.23421, -97.78471, 'Private room', 77, 2, 8, 0.09, 1, 320, 'Austin', '100 and below'),
#  (358, 'Terry', '78704', 30.24605, -97.74351, 'Entire home/apt', 300, 2, 6, 0.07, 1, 364, 'Austin', '200 to 400'),
#  (359, 'Eric', '78703', 30.27914, -97.75668, 'Entire home/apt', 229, 2, 48, 0.52, 1, 14, 'Austin', '200 to 400'),
#  (360, 'Katherine', '78704', 30.24494, -97.74004, 'Entire home/apt', 350, 30, 6, 0.07, 1, 303, 'Austin', '200 to 400'),
#  (361, 'Mark & Monica', '78751', 30.30295, -97.72932, 'Entire home/apt', 120, 2, 107, 1.17, 1, 0, 'Austin', '100 to 200'),
#  (362, 'Andrea', '78701', 30.27494, -97.75043, 'Private room', 148, 2, 3, 0.03, 1, 0, 'Austin', '100 to 200'),
#  (363, 'J', '78729', 30.45617, -97.75695, 'Private room', 74, 2, 41, 0.45, 1, 170, 'Austin', '100 and below'),
#  (364, "Jim O'", '78745', 30.20821, -97.77038, 'Entire home/apt', 15, 2, 14, 0.15, 14, 364, 'Austin', '100 and below'),
#  (365, 'Haley And Raul', '78741', 30.24315, -97.73452, 'Entire home/apt', 155, 28, 88, 0.96, 4, 291, 'Austin', '100 to 200'),
#  (366, 'Sevylla', '78744', 30.20087, -97.7533, 'Entire home/apt', 180, 3, 20, 0.22, 1, 352, 'Austin', '100 to 200'),
#  (367, 'Ryan', '78701', 30.26512, -97.73872, 'Entire home/apt', 118, 180, 0, None, 31, 283, 'Austin', '100 to 200'),
#  (368, 'Jonas', '78745', 30.19707, -97.80803, 'Entire home/apt', 500, 4, 0, None, 1, 365, 'Austin', '400 or more'),
#  (369, 'David', '78703', 30.27886, -97.75973, 'Entire home/apt', 500, 1, 7, 0.08, 1, 365, 'Austin', '400 or more'),
#  (370, 'Puru', '78753', 30.38086, -97.67032, 'Entire home/apt', 225, 3, 1, 0.01, 1, 358, 'Austin', '200 to 400'),
#  (371, 'Guadalupe', '78705', 30.29943, -97.73549, 'Entire home/apt', 65, 30, 179, 2.1, 1, 48, 'Austin', '100 and below'),
#  (372, 'Angie & Kurt', '78702', 30.26804, -97.72143, 'Entire home/apt', 700, 4, 0, None, 1, 0, 'Austin', '400 or more'),
#  (373, 'Scott', '78746', 30.27986, -97.79904, 'Entire home/apt', 900, 5, 0, None, 1, 365, 'Austin', '400 or more'),
#  (374, "Jim O'", '78745', 30.2095, -97.76914, 'Entire home/apt', 15, 2, 68, 0.74, 14, 365, 'Austin', '100 and below'),
#  (375, 'Mychal', '78722', 30.29115, -97.71075, 'Entire home/apt', 199, 3, 20, 0.22, 1, 136, 'Austin', '100 to 200'),
#  (376, 'Rob', '78723', 30.31371, -97.69227, 'Entire home/apt', 399, 5, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (377, 'Ben', '78702', 30.25977, -97.69713, 'Private room', 250, 3, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (378, 'Paul', '78701', 30.27545, -97.75, 'Entire home/apt', 120, 21, 8, 0.26, 1, 337, 'Austin', '100 to 200'),
#  (379, 'Austin', '78701', 30.26551, -97.74185, 'Entire home/apt', 203, 180, 162, 1.81, 14, 95, 'Austin', '200 to 400'),
#  (380, 'Marcella', '78723', 30.2994, -97.67747, 'Entire home/apt', 69, 1, 818, 8.88, 2, 313, 'Austin', '100 and below'),
#  (381, 'Kristen', '78701', 30.28086, -97.74529, 'Entire home/apt', 76, 1, 735, 8.01, 2, 328, 'Austin', '100 and below'),
#  (382, 'Luis', '78702', 30.26136, -97.71845, 'Entire home/apt', 114, 1, 78, 0.85, 1, 0, 'Austin', '100 to 200'),
#  (383, 'Amy', '78704', 30.24366, -97.73849, 'Entire home/apt', 151, 2, 202, 2.21, 1, 242, 'Austin', '100 to 200'),
#  (384, "Jim O'", '78745', 30.2086, -97.76882, 'Entire home/apt', 200, 3, 0, None, 14, 364, 'Austin', '100 to 200'),
#  (385, 'Chloe', '78741', 30.21833, -97.72652, 'Entire home/apt', 213, 2, 125, 1.55, 1, 352, 'Austin', '200 to 400'),
#  (386, 'Patrick And Michele', '78704', 30.26009, -97.77848, 'Entire home/apt', 1000, 4, 8, 0.43, 1, 28, 'Austin', '400 or more'),
#  (387, 'Jeannette', '78746', 30.32112, -97.8298, 'Private room', 350, 1, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (388, 'Donna', '78702', 30.25461, -97.7218, 'Entire home/apt', 88, 28, 216, 2.36, 2, 0, 'Austin', '100 and below'),
#  (389, 'Kate', '78702', 30.2523, -97.72553, 'Entire home/apt', 225, 2, 161, 1.76, 3, 16, 'Austin', '200 to 400'),
#  (390, 'John And Melissa', '78704', 30.25447, -97.76803, 'Entire home/apt', 150, 3, 156, 1.73, 1, 365, 'Austin', '100 to 200'),
#  (391, 'Tony', '78752', 30.32493, -97.71633, 'Entire home/apt', 317, 2, 157, 1.74, 1, 359, 'Austin', '200 to 400'),
#  (392, 'Willard', '78702', 30.27298, -97.71074, 'Private room', 49, 2, 9, 0.16, 1, 0, 'Austin', '100 and below'),
#  (393, 'Raquel + Jacob', '78701', 30.26993, -97.74358, 'Entire home/apt', 160, 1, 399, 4.47, 1, 166, 'Austin', '100 to 200'),
#  (394, 'Lauren', '78749', 30.21426, -97.84239, 'Private room', 49, 2, 3, 0.1, 2, 77, 'Austin', '100 and below'),
#  (395, 'Clay', '78702', 30.2731, -97.71986, 'Entire home/apt', 295, 3, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (396, 'Kate', '78702', 30.25041, -97.72592, 'Entire home/apt', 2200, 3, 2, 0.02, 3, 365, 'Austin', '400 or more'),
#  (397, 'Jim', '78704', 30.23405, -97.74964, 'Entire home/apt', 310, 2, 30, 0.78, 1, 144, 'Austin', '200 to 400'),
#  (398, "Jim O'", '78745', 30.20869, -97.77054, 'Entire home/apt', 15, 3, 16, 0.18, 14, 364, 'Austin', '100 and below'),
#  (399, "Jim O'", '78745', 30.21003, -97.7694, 'Entire home/apt', 15, 3, 13, 0.14, 14, 365, 'Austin', '100 and below'),
#  (400, 'Christina', '78702', 30.25107, -97.72451, 'Entire home/apt', 400, 3, 18, 0.23, 1, 179, 'Austin', '200 to 400'),
#  (401, 'Charlotte', '78704', 30.24645, -97.73831, 'Entire home/apt', 144, 3, 35, 0.49, 3, 0, 'Austin', '100 to 200'),
#  (402, 'Allix', '78703', 30.28991, -97.76323, 'Entire home/apt', 61, 30, 146, 2.35, 1, 226, 'Austin', '100 and below'),
#  (403, 'Kendel', '78704', 30.24415, -97.74386, 'Entire home/apt', 116, 30, 6, 0.07, 1, 318, 'Austin', '100 to 200'),
#  (404, 'Arif', '78704', 30.24423, -97.74777, 'Entire home/apt', 83, 3, 55, 0.65, 1, 365, 'Austin', '100 and below'),
#  (405, 'Roman', '78702', 30.25212, -97.72379, 'Entire home/apt', 67, 2, 406, 4.43, 2, 70, 'Austin', '100 and below'),
#  (406, 'Chris', '78705', 30.29822, -97.73275, 'Entire home/apt', 115, 3, 2, 0.11, 2, 362, 'Austin', '100 to 200'),
#  (407, 'Daniel', '78722', 30.28573, -97.72013, 'Private room', 200, 1, 1, 0.01, 1, 365, 'Austin', '100 to 200'),
#  (408, 'Benjamin', '78704', 30.22915, -97.7647, 'Private room', 260, 5, 3, 0.04, 2, 365, 'Austin', '200 to 400'),
# ...
#  (864, 'Barbara And Robert', '78704', 30.24621, -97.75179, 'Entire home/apt', 141, 2, 104, 1.46, 2, 134, 'Austin', '100 to 200'),
#  (865, 'Lodgewell', '78701', 30.26687, -97.74238, 'Entire home/apt', 130, 1, 120, 1.59, 39, 177, 'Austin', '100 to 200'),
#  (866, 'Lodgewell', '78701', 30.26699, -97.74144, 'Entire home/apt', 127, 1, 166, 2.21, 39, 177, 'Austin', '100 to 200'),
#  (867, 'Lodgewell', '78701', 30.26727, -97.74208, 'Entire home/apt', 144, 1, 131, 1.74, 39, 178, 'Austin', '100 to 200'),
#  (868, 'Kim', '78702', 30.2806, -97.70513, 'Entire home/apt', 150, 30, 1, 0.01, 1, 161, 'Austin', '100 to 200'),
#  (869, 'Kristine', '78745', 30.23122, -97.79382, 'Entire home/apt', 95, 1, 182, 2.51, 3, 358, 'Austin', '100 and below'),
#  (870, 'Lodgewell', '78701', 30.26693, -97.74081, 'Entire home/apt', 131, 1, 117, 1.64, 39, 176, 'Austin', '100 to 200'),
#  (871, 'Allison', '78704', 30.23825, -97.7491, 'Entire home/apt', 214, 2, 21, 0.31, 1, 0, 'Austin', '200 to 400'),
#  (872, 'Michael', '78703', 30.27846, -97.75301, 'Entire home/apt', 492, 1, 36, 0.49, 4, 364, 'Austin', '400 or more'),
#  (873, 'Eirian', '78704', 30.24412, -97.76086, 'Entire home/apt', 65, 68, 20, 0.27, 1, 320, 'Austin', '100 and below'),
#  (874, 'Pam', '78703', 30.28311, -97.76111, 'Entire home/apt', 150, 30, 17, 0.24, 1, 335, 'Austin', '100 to 200'),
#  (875, 'Katrina', '78702', 30.25726, -97.72581, 'Entire home/apt', 374, 1, 66, 0.9, 2, 218, 'Austin', '200 to 400'),
#  (876, 'Katherine & Andrew', '78723', 30.30996, -97.69963, 'Entire home/apt', 175, 2, 25, 0.34, 1, 280, 'Austin', '100 to 200'),
#  (877, 'Dani', '78704', 30.24409, -97.74013, 'Entire home/apt', 178, 1, 106, 1.47, 11, 16, 'Austin', '100 to 200'),
#  (878, 'Just', '78756', 30.33227, -97.7367, 'Entire home/apt', 99, 1, 281, 3.91, 1, 320, 'Austin', '100 and below'),
#  (879, 'Hope', '78702', 30.25361, -97.73135, 'Entire home/apt', 400, 1, 33, 0.46, 1, 26, 'Austin', '200 to 400'),
#  (880, 'Jana', '78704', 30.23499, -97.76168, 'Entire home/apt', 242, 2, 7, 0.1, 2, 283, 'Austin', '200 to 400'),
#  (881, 'Courtney', '78704', 30.25967, -97.77433, 'Entire home/apt', 250, 3, 2, 0.03, 1, 0, 'Austin', '200 to 400'),
#  (882, 'Renee', '78741', 30.22888, -97.73753, 'Entire home/apt', 400, 1, 4, 0.06, 1, 362, 'Austin', '200 to 400'),
#  (883, 'Brita', '78704', 30.25146, -97.75962, 'Entire home/apt', 150, 2, 25, 0.34, 1, 4, 'Austin', '100 to 200'),
#  (884, 'Carol', '78722', 30.30302, -97.71269, 'Private room', 56, 2, 323, 4.45, 1, 347, 'Austin', '100 and below'),
#  (885, 'Tanya', '78745', 30.22757, -97.8129, 'Private room', 155, 2, 1, 0.03, 1, 365, 'Austin', '100 to 200'),
#  (886, 'Nathan Stephen', '78723', 30.32093, -97.67448, 'Private room', 36, 2, 98, 1.94, 2, 0, 'Austin', '100 and below'),
#  (887, 'Peter', '78702', 30.26716, -97.72, 'Entire home/apt', 67, 1, 222, 3.07, 3, 36, 'Austin', '100 and below'),
#  (888, 'Barbara', '78737', 30.15793, -97.94311, 'Entire home/apt', 149, 2, 213, 2.95, 1, 326, 'Austin', '100 to 200'),
#  (889, 'Peter', '78702', 30.26725, -97.71996, 'Entire home/apt', 65, 1, 411, 6.48, 3, 92, 'Austin', '100 and below'),
#  (890, 'Hayley', '78703', 30.2785, -97.75191, 'Entire home/apt', 60, 30, 22, 0.31, 1, 230, 'Austin', '100 and below'),
#  (891, 'Regina', '78741', 30.24417, -97.73395, 'Entire home/apt', 289, 3, 6, 0.08, 1, 0, 'Austin', '200 to 400'),
#  (892, 'Sandy', '78759', 30.41766, -97.74375, 'Entire home/apt', 200, 1, 0, None, 1, 0, 'Austin', '100 to 200'),
#  (893, 'K', '78754', 30.33704, -97.64802, 'Entire home/apt', 99, 30, 8, 0.11, 5, 0, 'Austin', '100 and below'),
#  (894, 'Stephen', '78704', 30.24357, -97.75246, 'Entire home/apt', 57, 90, 3, 0.05, 2, 353, 'Austin', '100 and below'),
#  (895, 'Ben', '78702', 30.25508, -97.73041, 'Entire home/apt', 999, 2, 0, None, 1, 0, 'Austin', '400 or more'),
#  (896, 'Shaan', '78752', 30.32818, -97.68387, 'Private room', 51, 30, 5, 0.17, 2, 83, 'Austin', '100 and below'),
#  (897, 'Sunyong', '78702', 30.25811, -97.69755, 'Entire home/apt', 122, 2, 116, 1.62, 1, 259, 'Austin', '100 to 200'),
#  (898, 'Katelyn', '78751', 30.30631, -97.71525, 'Entire home/apt', 300, 1, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (899, 'Christina', '78703', 30.29135, -97.75996, 'Entire home/apt', 89, 30, 214, 2.9, 2, 90, 'Austin', '100 and below'),
#  (900, 'Anna', '78741', 30.22954, -97.71747, 'Entire home/apt', 100, 2, 37, 0.51, 1, 45, 'Austin', '100 and below'),
#  (901, 'Katherine', '78704', 30.25451, -97.76306, 'Private room', 111, 2, 102, 1.41, 1, 4, 'Austin', '100 to 200'),
#  (902, 'Snowflake', '78704', 30.25558, -97.76915, 'Entire home/apt', 1600, 2, 37, 0.51, 1, 362, 'Austin', '400 or more'),
#  (903, 'K', '78754', 30.33455, -97.65013, 'Private room', 38, 5, 120, 1.63, 5, 73, 'Austin', '100 and below'),
#  (904, 'Ted', '78721', 30.27875, -97.69171, 'Entire home/apt', 250, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (905, 'Diane', '78745', 30.19574, -97.81906, 'Private room', 75, 1, 1, 0.02, 1, 363, 'Austin', '100 and below'),
#  (906, 'Patricia', '78722', 30.29729, -97.71295, 'Entire home/apt', 126, 2, 80, 1.12, 1, 46, 'Austin', '100 to 200'),
#  (907, 'Brittany', '78751', 30.31378, -97.72381, 'Entire home/apt', 95, 1, 40, 1.01, 1, 0, 'Austin', '100 and below'),
#  (908, 'Vacasa Texas', '78704', 30.24857, -97.77704, 'Entire home/apt', 128, 2, 55, 0.76, 28, 350, 'Austin', '100 to 200'),
#  (909, 'Cressida', '78704', 30.24948, -97.75654, 'Entire home/apt', 150, 2, 39, 0.53, 1, 292, 'Austin', '100 to 200'),
#  (910, 'Fedora', '78705', 30.29877, -97.74464, 'Entire home/apt', 75, 5, 3, 0.33, 1, 0, 'Austin', '100 and below'),
#  (911, 'Kendall', '78704', 30.24355, -97.75931, 'Entire home/apt', 400, 3, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (912, 'Katie', '78705', 30.29683, -97.73049, 'Private room', 72, 1, 128, 1.77, 1, 0, 'Austin', '100 and below'),
#  (913, 'Josh', '78704', 30.26033, -97.77476, 'Entire home/apt', 500, 1, 0, None, 1, 365, 'Austin', '400 or more'),
#  (914, 'Mireille', '78703', 30.27383, -97.7563, 'Entire home/apt', 96, 1, 198, 2.71, 9, 360, 'Austin', '100 and below'),
#  (915, 'Marcus & Nora', '78731', 30.36448, -97.7871, 'Entire home/apt', 100, 3, 87, 1.34, 1, 162, 'Austin', '100 and below'),
#  (916, 'Angela', '78702', 30.25866, -97.72845, 'Entire home/apt', 1250, 2, 3, 0.04, 1, 260, 'Austin', '400 or more'),
#  (917, 'Kevin', '78746', 30.26937, -97.79374, 'Private room', 350, 3, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (918, 'Kaley', '78703', 30.28517, -97.76185, 'Private room', 50, 4, 2, 0.03, 1, 0, 'Austin', '100 and below'),
#  (919, 'Ted', '78701', 30.27427, -97.74698, 'Entire home/apt', 137, 2, 218, 3.5, 2, 238, 'Austin', '100 to 200'),
#  (920, 'Ted', '78701', 30.27506, -97.74621, 'Private room', 122, 1, 150, 2.21, 2, 311, 'Austin', '100 to 200'),
#  (921, 'Janie', '78731', 30.31425, -97.74973, 'Entire home/apt', 122, 2, 94, 1.31, 1, 354, 'Austin', '100 to 200'),
#  (922, 'Chalu', '78704', 30.2364, -97.77844, 'Entire home/apt', 109, 2, 86, 1.19, 9, 74, 'Austin', '100 to 200'),
#  (923, 'Amit', '78702', 30.25474, -97.73612, 'Entire home/apt', 236, 2, 199, 2.73, 4, 309, 'Austin', '200 to 400'),
#  (924, 'Jill', '78704', 30.23353, -97.77978, 'Entire home/apt', 265, 1, 93, 1.31, 3, 365, 'Austin', '200 to 400'),
#  (925, 'Robin', '78704', 30.23776, -97.77344, 'Private room', 145, 2, 49, 0.73, 1, 363, 'Austin', '100 to 200'),
#  (926, 'Rick', '78704', 30.25557, -97.77, 'Entire home/apt', 95, 2, 60, 0.88, 1, 0, 'Austin', '100 and below'),
#  (927, 'Louis', '78703', 30.29366, -97.77791, 'Entire home/apt', 183, 3, 12, 0.2, 1, 106, 'Austin', '100 to 200'),
#  (928, 'Cole', '78730', 30.36015, -97.80268, 'Entire home/apt', 495, 4, 0, None, 1, 0, 'Austin', '400 or more'),
#  (929, 'Jorge', '78758', 30.36577, -97.7131, 'Private room', 50, 1, 8, 0.12, 1, 291, 'Austin', '100 and below'),
#  (930, 'Ryan', '78701', 30.26647, -97.74243, 'Entire home/apt', 80, 2, 99, 1.36, 31, 311, 'Austin', '100 and below'),
#  (931, 'Ryan', '78701', 30.26409, -97.74107, 'Entire home/apt', 182, 2, 179, 2.46, 31, 360, 'Austin', '100 to 200'),
#  (932, 'Meredith', '78702', 30.27738, -97.707, 'Entire home/apt', 117, 1, 281, 3.85, 5, 342, 'Austin', '100 to 200'),
#  (933, 'Ely', '78702', 30.25489, -97.73406, 'Entire home/apt', 299, 2, 3, 0.04, 1, 0, 'Austin', '200 to 400'),
#  (934, 'Jackie', '78751', 30.30487, -97.72053, 'Entire home/apt', 128, 2, 126, 1.83, 1, 119, 'Austin', '100 to 200'),
#  (935, 'Rico', '78757', 30.34264, -97.73876, 'Entire home/apt', 79, 2, 14, 1.21, 1, 12, 'Austin', '100 and below'),
#  (936, 'Caroline', '78751', 30.31092, -97.71607, 'Entire home/apt', 225, 1, 24, 0.36, 1, 260, 'Austin', '200 to 400'),
#  (937, 'Jay', '78704', 30.26149, -97.76949, 'Entire home/apt', 149, 2, 88, 1.33, 21, 326, 'Austin', '100 to 200'),
#  (938, 'Steve', '78703', 30.28527, -97.77234, 'Entire home/apt', 189, 2, 54, 0.78, 1, 0, 'Austin', '100 to 200'),
#  (939, 'Peter', '78745', 30.22291, -97.77774, 'Entire home/apt', 132, 2, 159, 2.22, 1, 138, 'Austin', '100 to 200'),
#  (940, 'Julie', '78741', 30.23139, -97.69459, 'Entire home/apt', 150, 30, 15, 0.21, 1, 284, 'Austin', '100 to 200'),
#  (941, 'Kristofer', '78704', 30.25604, -97.75157, 'Entire home/apt', 2100, 3, 0, None, 1, 0, 'Austin', '400 or more'),
#  (942, 'Scott And Sally', '78745', 30.21302, -97.79138, 'Entire home/apt', 410, 4, 5, 0.08, 11, 352, 'Austin', '400 or more'),
#  (943, 'Melissa', '78703', 30.27855, -97.77102, 'Entire home/apt', 623, 2, 98, 1.35, 2, 2, 'Austin', '400 or more'),
#  (944, 'Mari', '78751', 30.3149, -97.71887, 'Entire home/apt', 390, 4, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (945, 'Vacasa Texas', '78704', 30.24681, -97.74188, 'Entire home/apt', 100, 2, 156, 2.16, 28, 359, 'Austin', '100 and below'),
#  (946, 'James', '78736', 30.23514, -97.9381, 'Entire home/apt', 97, 1, 16, 0.24, 1, 0, 'Austin', '100 and below'),
#  (947, 'Scott And Sally', '78758', 30.35414, -97.71039, 'Entire home/apt', 166, 4, 44, 0.63, 11, 227, 'Austin', '100 to 200'),
#  (948, 'Cassady', '78704', 30.24203, -97.75162, 'Entire home/apt', 375, 2, 15, 0.31, 1, 0, 'Austin', '200 to 400'),
#  (949, 'Don', '78704', 30.25298, -97.75414, 'Entire home/apt', 600, 2, 0, None, 1, 0, 'Austin', '400 or more'),
#  (950, 'Melanie', '78729', 30.44925, -97.76088, 'Entire home/apt', 206, 2, 35, 0.49, 1, 336, 'Austin', '200 to 400'),
#  (951, 'Pierce', '78704', 30.25258, -97.74881, 'Entire home/apt', 400, 2, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (952, 'Brenton', '78731', 30.37425, -97.75932, 'Entire home/apt', 300, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (953, 'Anna', '78723', 30.29943, -97.70264, 'Entire home/apt', 200, 2, 48, 0.69, 1, 0, 'Austin', '100 to 200'),
#  (954, 'Whitney', '78704', 30.24099, -97.76308, 'Entire home/apt', 183, 4, 45, 0.62, 2, 138, 'Austin', '100 to 200'),
#  (955, 'Merita', '78702', 30.26588, -97.70516, 'Entire home/apt', 135, 7, 41, 0.66, 1, 0, 'Austin', '100 to 200'),
#  (956, 'Joaquin', '78704', 30.25961, -97.77315, 'Entire home/apt', 125, 5, 1, 0.04, 1, 0, 'Austin', '100 to 200'),
#  (957, 'Cavason', '78745', 30.22165, -97.79177, 'Entire home/apt', 150, 1, 0, None, 1, 0, 'Austin', '100 to 200'),
#  (958, 'Paxton', '78741', 30.23974, -97.71624, 'Private room', 30, 1, 1, 0.02, 1, 0, 'Austin', '100 and below'),
#  (959, 'Joey', '78703', 30.28323, -97.76378, 'Entire home/apt', 88, 2, 134, 1.94, 1, 0, 'Austin', '100 and below'),
#  (960, 'Annecy', '78703', 30.2835, -97.76287, 'Entire home/apt', 450, 1, 2, 0.03, 1, 365, 'Austin', '400 or more'),
#  (961, 'Michael', '78703', 30.27574, -97.76426, 'Entire home/apt', 650, 1, 0, None, 1, 0, 'Austin', '400 or more'),
#  (962, 'Jake Thomas', '78748', 30.18544, -97.80978, 'Private room', 50, 1, 2, 0.03, 1, 0, 'Austin', '100 and below'),
#  (963, 'Judi', '78756', 30.30648, -97.74563, 'Entire home/apt', 144, 2, 14, 0.2, 1, 17, 'Austin', '100 to 200'),
#  (964, 'Kristen', '78702', 30.26062, -97.72726, 'Entire home/apt', 89, 2, 38, 0.53, 1, 0, 'Austin', '100 and below'),
#  (965, 'Ricky', '78704', 30.23438, -97.76625, 'Entire home/apt', 750, 83, 0, None, 1, 363, 'Austin', '400 or more'),
#  (966, 'David', '78721', 30.27394, -97.68803, 'Entire home/apt', 75, 1, 62, 0.86, 2, 324, 'Austin', '100 and below'),
#  (967, 'Jason', '78704', 30.22619, -97.75558, 'Entire home/apt', 99, 2, 55, 0.76, 3, 186, 'Austin', '100 and below'),
#  (968, 'Joe And Susan', '78702', 30.25715, -97.72585, 'Entire home/apt', 102, 2, 271, 3.75, 1, 292, 'Austin', '100 to 200'),
#  (969, 'Katheryn', '78733', 30.34016, -97.85317, 'Entire home/apt', 196, 2, 72, 1.07, 1, 353, 'Austin', '100 to 200'),
#  (970, 'Brett', '78701', 30.27858, -97.74782, 'Entire home/apt', 107, 1, 513, 7.89, 8, 147, 'Austin', '100 to 200'),
#  (971, 'Priya', '78704', 30.24133, -97.78012, 'Entire home/apt', 98, 2, 17, 0.23, 2, 0, 'Austin', '100 and below'),
#  (972, 'Adriana', '78703', 30.2963, -97.78163, 'Entire home/apt', 150, 3, 0, None, 2, 0, 'Austin', '100 to 200'),
#  (973, 'Sarah', '78702', 30.25805, -97.72995, 'Entire home/apt', 129, 7, 233, 3.24, 1, 0, 'Austin', '100 to 200'),
#  (974, 'Lodgewell', '78704', 30.24329, -97.75272, 'Entire home/apt', 129, 1, 193, 2.66, 39, 75, 'Austin', '100 to 200'),
#  (975, 'Lodgewell', '78701', 30.26677, -97.74222, 'Entire home/apt', 265, 1, 115, 1.58, 39, 170, 'Austin', '200 to 400'),
#  (976, 'Allison', '78704', 30.25989, -97.77026, 'Entire home/apt', 300, 2, 0, None, 2, 0, 'Austin', '200 to 400'),
#  (977, 'Jessica', '78746', 30.25796, -97.79216, 'Entire home/apt', 250, 1, 0, None, 2, 0, 'Austin', '200 to 400'),
#  (978, 'George', '78745', 30.21996, -97.77604, 'Entire home/apt', 165, 2, 141, 1.96, 1, 339, 'Austin', '100 to 200'),
#  (979, 'Lodgewell', '78701', 30.26811, -97.74089, 'Entire home/apt', 337, 1, 119, 1.68, 39, 177, 'Austin', '200 to 400'),
#  (980, 'Jessica', '78746', 30.25869, -97.79181, 'Entire home/apt', 250, 1, 0, None, 2, 0, 'Austin', '200 to 400'),
#  (981, 'Lodgewell', '78701', 30.26664, -97.74145, 'Entire home/apt', 127, 1, 156, 2.14, 39, 177, 'Austin', '100 to 200'),
#  (982, 'Martin', '78704', 30.23896, -97.76055, 'Entire home/apt', 300, 3, 11, 0.17, 1, 0, 'Austin', '200 to 400'),
#  (983, 'Lodgewell', '78701', 30.26789, -97.74226, 'Entire home/apt', 151, 1, 149, 2.07, 39, 167, 'Austin', '100 to 200'),
#  (984, 'Lodgewell', '78701', 30.26731, -97.74213, 'Entire home/apt', 140, 1, 120, 1.66, 39, 174, 'Austin', '100 to 200'),
#  (985, 'Vacasa Texas', '78703', 30.27984, -97.76494, 'Entire home/apt', 156, 1, 62, 0.87, 28, 363, 'Austin', '100 to 200'),
#  (986, 'Roland', '78723', 30.32019, -97.68427, 'Entire home/apt', 89, 2, 310, 4.29, 2, 251, 'Austin', '100 and below'),
#  (987, 'James', '78704', 30.25857, -97.77281, 'Entire home/apt', 745, 3, 0, None, 1, 365, 'Austin', '400 or more'),
#  (988, 'Jeremy', '78703', 30.28365, -97.75847, 'Entire home/apt', 500, 1, 0, None, 1, 0, 'Austin', '400 or more'),
#  (989, 'Roanna', '78756', 30.32241, -97.74227, 'Entire home/apt', 125, 2, 43, 0.6, 1, 326, 'Austin', '100 to 200'),
#  (990, 'Jeff', '78746', 30.2583, -97.79145, 'Entire home/apt', 250, 2, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (991, 'Veronica', '78727', 30.43249, -97.69418, 'Entire home/apt', 500, 1, 0, None, 1, 365, 'Austin', '400 or more'),
#  (992, 'Jack', '78704', 30.2632, -97.76294, 'Private room', 73, 2, 151, 2.09, 2, 62, 'Austin', '100 and below'),
#  (993, 'Jd', '78704', 30.26521, -97.76285, 'Entire home/apt', 2500, 2, 7, 0.1, 2, 365, 'Austin', '400 or more'),
#  (994, 'Madison', '78749', 30.23081, -97.83434, 'Entire home/apt', 400, 2, 0, None, 1, 365, 'Austin', '200 to 400'),
#  (995, 'Ben', '78746', 30.25941, -97.7898, 'Entire home/apt', 400, 1, 0, None, 1, 0, 'Austin', '200 to 400'),
#  (996, 'Rick & Sandi', '78723', 30.30871, -97.68998, 'Entire home/apt', 452, 2, 138, 1.92, 1, 256, 'Austin', '400 or more'),
#  (997, 'Nathalie', '78745', 30.21366, -97.80912, 'Entire home/apt', 150, 30, 23, 0.32, 1, 314, 'Austin', '100 to 200'),
#  (998, 'Saurabh', '78704', 30.26101, -97.77188, 'Private room', 80, 1, 15, 0.23, 2, 89, 'Austin', '100 and below'),
#  (999, "Jim O'", '78745', 30.21034, -97.77074, 'Private room', 35, 3, 49, 0.68, 14, 365, 'Austin', '100 and below'),
#  ...]

# %%
# Create CW Class

# class AA2(Base):
#     __tablename__ = 'Airbnb_Analysis'
#     __table_args__ = {'extend_existing': True}
#     id = Column(Integer, primary_key=True)
#     Host_Name = Column(String(255))
#     Neighbourhood = Column(String(255))
#     Latitude = Column(String(255))
#     Longitude = Column(String(255))
#     Room_Type = Column(String(255))
#     Price = Column(Float)
#     Minimum_Nights = Column(Float)
#     Number_of_Reviews = Column(Float)
#     Reviews_Per_Month = Column(Float)
#     Calculated_Host_Listings_Count = Column(Float)
#     Availability_365 = Column(Float)
#     City = Column(String(255))
#     Price_Bins = Column(String(255))

# %%
# Create Database Connection
# ----------------------------------
# Establish Connection
# engine = create_engine("sqlite:///Airbnb_Analysis.sqlite")
# conn = engine.connect()
# Base.metadata.create_all(conn)

# %%
# from sqlalchemy.orm import Session
session = Session(bind=engine)
session.commit()

# for x in range(len(newdf2)):
#     info = AA(id = x+1,
#             Host_Name = newdf2['host_name'][x],
#             Neighbourhood = newdf2['neighbourhood'][x],
#             Latitude = newdf2['latitude'][x],
#             Longitude = newdf2['longitude'][x],
#             Room_Type = newdf2['room_type'][x],
#             Price = newdf2['price'][x],
#             Minimum_Nights = newdf2['minimum_nights'][x],
#             Number_of_Reviews = newdf2['number_of_reviews'][x],
#             Reviews_Per_Month = newdf2['reviews_per_month'][x],
#             Calculated_Host_Listings_Count = newdf2['calculated_host_listings_count'][x],
#             Availability_365 = newdf2['availability_365'][x],
#             City = newdf2['city'][x],
#             Price_Bins = newdf2['price_bins'][x]
#             )
#     session.add(info)
#     session.commit()

# %%
#step 1:add states to the dataframe - NO
#step2: by year = total number of reviews for each property.....groupby(host,year,state) -  
#visualize by city, type, cost bins
#look for crime stats by zipcode
# mouse over # ratings, availability, 
#streetview
#dropdown
# house view
#price distribution across state with heatmap. - tourist attraction
#dropdown price distribution (heatmap, cholorepht)
#house type/price range 

Cluster and heatmap - Raheem
cholorepht and Overlay maps - Vi

# %%
import requests

url = "https://crimescore.p.rapidapi.com/crimescore"

querystring = {"lat":"38.08809","lon":"-85.679626","f":"json","id":"174"}

headers = {
    'x-rapidapi-host': "crimescore.p.rapidapi.com",
    'x-rapidapi-key': "SIGN-UP-FOR-KEY"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
